# %% [markdown]
# # Neural Networks & Deep Learning HomeWork 02
# This is the second homework of NNDL course
# By
# * Ali Ranjbari, 810198570
# * AmirHossein Alizad, 810197000

# %% [markdown]
# ## 0. Importing and define some utils functions

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      |████████████████████████████████| 529 kB 36.7 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.1+cu113)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.10.3

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torchmetrics
from torchmetrics.functional.classification import (
    multiclass_accuracy,
    multiclass_precision,
    multiclass_f1_score)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device is {device}')
# Out:
# device is cuda

# %% [markdown]
# First some utils fucntion

# %%
def train(model, dataset, criterion, optimizer, num_epochs, batch_size, verbose=True) -> dict:
  
  data_loader = torch.utils.data.DataLoader(dataset,
                                                 batch_size=batch_size,
                                                 shuffle=True)


  results = {'accuracy':[], 'loss':[], 'precision':[], 'f1_score':[]}
  n_total_steps = len(data_loader)
  for epoch in range(num_epochs):
    if verbose:
      print(f"***** Epoch {epoch+1} of {num_epochs} *****")
      
    for i, (images, labels) in enumerate(data_loader):
      images = images.to(device)
      labels = labels.to(device)

      outputs = model(images)
      loss = criterion(outputs, labels)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      
    
    # Add accuracy, precision, F1
    preds = []
    y = []
    with torch.no_grad():
      for (i, l) in data_loader:
        i = i.to(device)
        l = l.to(device)

        preds.append(model(i))
        y.append(l)


    preds = torch.concat(preds, dim=0)
    y = torch.concat(y, dim=0)
    acc = multiclass_accuracy(preds, y, num_classes=10).item()
    prec = multiclass_precision(preds, y, num_classes=10).item()
    f1 = multiclass_f1_score(preds, y, num_classes=10).item()
    results['accuracy'].append(acc)
    results['loss'].append(loss.item())
    results['precision'].append(prec)
    results['f1_score'].append(f1)
    if verbose:
      print(f"Total Loss : {loss.item():.4f}")
      print(f"Accuracy   : {acc*100:.2f} %")
      print(f"Precision  : {prec*100:.2f} %")
      print(f"F1 score   : {f1*100:.2f} %\n")
  return results

# %%
def test(model, dataset, batch_size, verbose=False):

  data_loader = torch.utils.data.DataLoader(dataset,
                                                batch_size=batch_size,
                                                shuffle=True)

  preds = []
  y = []
  with torch.no_grad():
    for (i, l) in data_loader:
      i = i.to(device)
      l = l.to(device)

      preds.append(model(i))
      y.append(l)


  preds = torch.concat(preds, dim=0)
  y = torch.concat(y, dim=0)
  acc = multiclass_accuracy(preds, y, num_classes=10).item()
  prec = multiclass_precision(preds, y, num_classes=10).item()
  f1 = multiclass_f1_score(preds, y, num_classes=10).item()


  if verbose:
    print(f"Accuracy: {acc:.2f}, Precision: {prec:.2f}, F1 Score: {f1:.2f}")

  return acc, prec, f1

# %%
def show_image(img):
  npimg = img.numpy()
  np_tr = np.transpose(npimg, (1,2,0))
  print(np_tr.shape)
  plt.imshow(np_tr)
  plt.show()
def show_labels(labels):
  names = []
  for i in labels:
    names.append(classes[i.item()])
  return names

# %% [markdown]
# ## 1. Effects of Varying Resolution on Performance of **CNN** based Image Classification

# %%
transform32 = transforms.Compose([
    transforms.ToTensor(),
])
transform16 = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(16)
])
transform8 = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(8)
])
transform_to_32 = transforms.Compose([
    transforms.Resize(32),
])

# %%
train_cifar = torchvision.datasets.CIFAR10(root="./data", train=True,
                                                  download=True, transform=transform32)
test_cifar = torchvision.datasets.CIFAR10(root="./data", train=False,
                                                  download=True, transform=transform32)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
cifar_train_dataset32 = torchvision.datasets.CIFAR10(root="./data", train=True,
                                                  download=True, transform=transform32)
cifar_test_dataset32 = torchvision.datasets.CIFAR10(root="./data", train=False,
                                                  download=True, transform=transform32)
cifar_train_dataset16 = torchvision.datasets.CIFAR10(root="./data", train=True,
                                                  download=True, transform=transform16)
cifar_test_dataset16 = torchvision.datasets.CIFAR10(root="./data", train=False,
                                                  download=True, transform=transform16)
cifar_train_dataset8 = torchvision.datasets.CIFAR10(root="./data", train=True,
                                                  download=True, transform=transform8)
cifar_test_dataset8 = torchvision.datasets.CIFAR10(root="./data", train=False,
                                                  download=True, transform=transform8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
rand_idx = torch.randint(0,1000, (10,))
figure, axis = plt.subplots(10, 3, figsize=(32,32))
for i in range(10):
  idx = torch.randint(0,1000, (1,)).item()
  # getting images
  img_32 = cifar_train_dataset32[idx][0].numpy()
  img_16 = cifar_train_dataset16[idx][0].numpy()
  img_8 = cifar_train_dataset8[idx][0].numpy()
  # transpose
  img_32 = np.transpose(img_32, (1,2,0))
  img_16 = np.transpose(img_16, (1,2,0))
  img_8 = np.transpose(img_8, (1,2,0))
  # plot
  axis[i,0].imshow(img_32)
  axis[i,1].imshow(img_16)
  axis[i,2].imshow(img_8)

# plt.subplots_adjust(wspace=-1,hspace=0)
plt.show()

# %% [markdown]
# Train test validation splits
# it is 84% train and 16% test

# %%
print("train dataset size: ", len(cifar_train_dataset32))
print("test datset size:", len(cifar_test_dataset32))
print(len(cifar_train_dataset32)/(len(cifar_train_dataset32)+len(cifar_test_dataset32)))
# Out:
# train dataset size:  50000
# test datset size: 10000
# 0.8333333333333334

# %% [markdown]
# ### Define the models
# Here we define three different models for 32\*32, 16\*16 and 8\*8

# %% [markdown]
# First model for 32*32

# %%
class cifar32_CNN(nn.Module):
  def __init__(self, input_size = 32):
    super().__init__()

    #layer 1, Conv
    self.conv1_1 = nn.Conv2d(3, 32, 3)    
    self.conv1_2 = nn.Conv2d(32, 32, 3)   
    self.conv1_3 = nn.Conv2d(32, 32, 3)   
    self.pool1 = nn.MaxPool2d(2, 2)       
    self.dropout1 = nn.Dropout(0.25)
  
    self.output_size = int((input_size-6)/2)

    # layer 2, Conv
    self.conv2_1 = nn.Conv2d(32, 64, 3)   
    self.conv2_2 = nn.Conv2d(64, 64, 3)   
    self.conv2_3 = nn.Conv2d(64, 64, 3)   
    self.pool2 = nn.MaxPool2d(2, 2)       
    self.dropout2 = nn.Dropout(0.25)

    self.output_size = int((self.output_size-6)/2)

    # layer 3, Linear    
    self.fc3 = nn.Linear(64*self.output_size*self.output_size, 512)   
    self.dropout3 = nn.Dropout(0.5)
    
    # layer 4, Output
    self.fc4 = nn.Linear(512, 10)
    

  def forward(self, x):
    
    # layer 1, Conv
    x = F.relu(self.conv1_1(x))
    x = F.relu(self.conv1_2(x))
    x = F.relu(self.conv1_3(x))
    x = self.dropout1(self.pool1(x))

    # layer 2, Conv2
    x = F.relu(self.conv2_1(x))
    x = F.relu(self.conv2_2(x))
    x = F.relu(self.conv2_3(x))
    x = self.dropout2(self.pool2(x))

    x = x.view(-1, 64*self.output_size*self.output_size)
    # layer 3, Linear
    x = F.relu(self.fc3(x))
    x = self.dropout3(x)

    # conv 4, Output
    x = self.fc4(x)
    
    return x

# %% [markdown]
# Model for 16*16 dataset

# %%
class cifar16_CNN(nn.Module):
  def __init__(self, input_size = 16):
    super().__init__()

    #layer 1, Conv
    self.conv1_1 = nn.Conv2d(3, 32, 3)    
    self.pool1 = nn.MaxPool2d(2, 2)       
    self.dropout1 = nn.Dropout(0.25)

    self.output_size = int((input_size-2)/2)

    
    # layer 2, Conv
    self.conv2_1 = nn.Conv2d(32, 64, 3)     
    self.pool2 = nn.MaxPool2d(2, 2)       
    self.dropout2 = nn.Dropout(0.25)

    self.output_size = int((self.output_size-2)/2)

    # layer 3, Linear    
    self.fc3 = nn.Linear(64*self.output_size*self.output_size, 512)   
    self.dropout3 = nn.Dropout(0.5)
    
    # layer 4, Output
    self.fc4 = nn.Linear(512, 10)
    

  def forward(self, x):
    
    # layer 1, Conv
    x = F.relu(self.conv1_1(x))
    x = self.dropout1(self.pool1(x))

    # layer 2, Conv2
    x = F.relu(self.conv2_1(x))
    x = self.dropout2(self.pool2(x))

    x = x.view(-1, 64*self.output_size*self.output_size)
    # layer 3, Linear
    x = F.relu(self.fc3(x))
    x = self.dropout3(x)

    # conv 4, Output
    x = self.fc4(x)
    
    return x

# %% [markdown]
# Now define a model for 8*8 dataset

# %%
class cifar8_CNN(nn.Module):
  def __init__(self, input_size = 8):
    super().__init__()

    #layer 1, Conv
    self.conv1_1 = nn.Conv2d(3, 32, 3)  
    self.conv1_2 = nn.Conv2d(32, 32, 3)  
    self.pool1 = nn.MaxPool2d(2, 2)
    self.dropout1 = nn.Dropout(0.25)

    self.output_size = int((input_size-4)/2)


    # layer 3, Linear    
    self.fc3 = nn.Linear(32*self.output_size*self.output_size, 512)   
    self.dropout3 = nn.Dropout(0.5)
    
    # layer 4, Output
    self.fc4 = nn.Linear(512, 10)
    

  def forward(self, x):
    
    # layer 1, Conv
    x = F.relu(self.conv1_1(x))
    x = F.relu(self.conv1_2(x))
    x = self.dropout1(self.pool1(x))

    x = x.view(-1, 32*self.output_size*self.output_size)
    # layer 3, Linear
    x = F.relu(self.fc3(x))
    x = self.dropout3(x)

    # conv 4, Output
    x = self.fc4(x)
    
    return x

# %% [markdown]
# ### Train
# First training the three models for 32\*32, 16\*16 and 8\*8

# %%
model32 = cifar32_CNN(input_size=32).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model32.parameters(), lr=0.002)

results = train(
              model32,
              cifar_train_dataset32,
              criterion,
              optimizer,
              num_epochs = 100,
              batch_size = 256,
              verbose=True)

# saving the modle
torch.save(model32.state_dict(), f"./cifar_model32_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 100 *****
# Total Loss : 2.0042
# Accuracy   : 32.52 %
# Precision  : 32.69 %
# F1 score   : 31.59 %
#
# ***** Epoch 2 of 100 *****
# Total Loss : 1.4602
# Accuracy   : 43.85 %
# Precision  : 42.96 %
# F1 score   : 42.86 %
#
# ***** Epoch 3 of 100 *****
# Total Loss : 1.6210
# Accuracy   : 49.23 %
# Precision  : 48.47 %
# F1 score   : 47.36 %
#
# ***** Epoch 4 of 100 *****
# Total Loss : 1.2445
# Accuracy   : 53.15 %
# Precision  : 53.92 %
# F1 score   : 52.37 %
#
# ***** Epoch 5 of 100 *****
# Total Loss : 1.1506
# Accuracy   : 56.66 %
# Precision  : 55.67 %
# F1 score   : 55.28 %
#
# ***** Epoch 6 of 100 *****
# Total Loss : 1.1085
# Accuracy   : 58.75 %
# Precision  : 60.50 %
# F1 score   : 58.83 %
#
# ***** Epoch 7 of 100 *****
# Total Loss : 0.8484
# Accuracy   : 61.72 %
# Precision  : 61.48 %
# F1 score   : 60.81 %
#
# ***** Epoch 8 of 100 *****
# Total Loss : 1.1955
# Accuracy   : 60.52 %
# Precision  : 63.40 %
# F1 score   : 60.05 %
#
# ***** Epoch 9 of 100 *****
# Total Loss : 1.0760
# Accuracy   : 64.55 %
# Precision  : 66.23 %
# F1 score   : 64.69 %
#
# ***** Epoch 10 of 100 *****
# Total Loss : 0.9891
# Accuracy   : 65.53 %
# Precision  : 65.29 %
# F1 score   : 64.72 %
#
# ***** Epoch 11 of 100 *****
# Total Loss : 0.8935
# Accuracy   : 67.70 %
# Precision  : 68.85 %
# F1 score   : 67.99 %
#
# ***** Epoch 12 of 100 *****
# Total Loss : 0.8800
# Accuracy   : 67.53 %
# Precision  : 68.35 %
# F1 score   : 67.28 %
#
# ***** Epoch 13 of 100 *****
# Total Loss : 0.7846
# Accuracy   : 70.41 %
# Precision  : 70.46 %
# F1 score   : 70.16 %
#
# ***** Epoch 14 of 100 *****
# Total Loss : 0.9010
# Accuracy   : 70.20 %
# Precision  : 70.20 %
# F1 score   : 69.79 %
#
# ***** Epoch 15 of 100 *****
# Total Loss : 1.1531
# Accuracy   : 70.18 %
# Precision  : 71.91 %
# F1 score   : 70.46 %
#
# ***** Epoch 16 of 100 *****
# Total Loss : 0.7751
# Accuracy   : 69.42 %
# Precision  : 71.93 %
# F1 score   : 70.00 %
#
# ***** Epoch 17 of 100 *****
# Total Loss : 0.7460
# Accuracy   : 71.98 %
# Precision  : 71.81 %
# F1 score   : 71.65 %
#
# ***** Epoch 18 of 100 *****
# Total Loss : 0.9454
# Accuracy   : 72.25 %
# Precision  : 72.98 %
# F1 score   : 72.30 %
#
# ***** Epoch 19 of 100 *****
# Total Loss : 0.9623
# Accuracy   : 72.63 %
# Precision  : 73.48 %
# F1 score   : 72.67 %
#
# ***** Epoch 20 of 100 *****
# Total Loss : 0.9588
# Accuracy   : 72.52 %
# Precision  : 73.54 %
# F1 score   : 72.58 %
#
# ***** Epoch 21 of 100 *****
# Total Loss : 0.7005
# Accuracy   : 72.46 %
# Precision  : 72.63 %
# F1 score   : 72.23 %
#
# ***** Epoch 22 of 100 *****
# Total Loss : 0.7544
# Accuracy   : 73.69 %
# Precision  : 74.52 %
# F1 score   : 73.72 %
#
# ***** Epoch 23 of 100 *****
# Total Loss : 0.7673
# Accuracy   : 74.42 %
# Precision  : 74.45 %
# F1 score   : 74.29 %
#
# ***** Epoch 24 of 100 *****
# Total Loss : 0.7459
# Accuracy   : 74.82 %
# Precision  : 75.01 %
# F1 score   : 74.65 %
#
# ***** Epoch 25 of 100 *****
# Total Loss : 0.8007
# Accuracy   : 74.36 %
# Precision  : 74.67 %
# F1 score   : 74.27 %
#
# ***** Epoch 26 of 100 *****
# Total Loss : 0.7043
# Accuracy   : 75.30 %
# Precision  : 75.75 %
# F1 score   : 75.37 %
#
# ***** Epoch 27 of 100 *****
# Total Loss : 0.6855
# Accuracy   : 75.65 %
# Precision  : 75.42 %
# F1 score   : 75.35 %
#
# ***** Epoch 28 of 100 *****
# Total Loss : 0.7619
# Accuracy   : 75.18 %
# Precision  : 75.85 %
# F1 score   : 75.25 %
#
# ***** Epoch 29 of 100 *****
# Total Loss : 0.6045
# Accuracy   : 76.24 %
# Precision  : 76.58 %
# F1 score   : 76.32 %
#
# ***** Epoch 30 of 100 *****
# Total Loss : 0.6628
# Accuracy   : 76.36 %
# Precision  : 76.15 %
# F1 score   : 76.10 %
#
# ***** Epoch 31 of 100 *****
# Total Loss : 0.9511
# Accuracy   : 76.67 %
# Precision  : 76.70 %
# F1 score   : 76.54 %
#
# ***** Epoch 32 of 100 *****
# Total Loss : 0.9406
# Accuracy   : 76.09 %
# Precision  : 76.43 %
# F1 score   : 76.03 %
#
# ***** Epoch 33 of 100 *****
# Total Loss : 0.8814
# Accuracy   : 76.12 %
# Precision  : 76.43 %
# F1 score   : 76.02 %
#
# ***** Epoch 34 of 100 *****
# Total Loss : 0.6881
# Accuracy   : 75.65 %
# Precision  : 75.81 %
# F1 score   : 75.49 %
#
# ***** Epoch 35 of 100 *****
# Total Loss : 0.5018
# Accuracy   : 77.74 %
# Precision  : 77.79 %
# F1 score   : 77.68 %
#
# ***** Epoch 36 of 100 *****
# Total Loss : 0.6680
# Accuracy   : 75.73 %
# Precision  : 76.63 %
# F1 score   : 76.02 %
#
# ***** Epoch 37 of 100 *****
# Total Loss : 0.5451
# Accuracy   : 77.02 %
# Precision  : 76.95 %
# F1 score   : 76.78 %
#
# ***** Epoch 38 of 100 *****
# Total Loss : 0.5605
# Accuracy   : 76.51 %
# Precision  : 76.51 %
# F1 score   : 76.34 %
#
# ***** Epoch 39 of 100 *****
# Total Loss : 0.7669
# Accuracy   : 76.18 %
# Precision  : 77.14 %
# F1 score   : 76.29 %
#
# ***** Epoch 40 of 100 *****
# Total Loss : 0.6701
# Accuracy   : 77.74 %
# Precision  : 77.82 %
# F1 score   : 77.73 %
#
# ***** Epoch 41 of 100 *****
# Total Loss : 0.6500
# Accuracy   : 77.12 %
# Precision  : 77.16 %
# F1 score   : 76.98 %
#
# ***** Epoch 42 of 100 *****
# Total Loss : 0.6229
# Accuracy   : 77.22 %
# Precision  : 77.46 %
# F1 score   : 77.19 %
#
# ***** Epoch 43 of 100 *****
# Total Loss : 0.7736
# Accuracy   : 77.60 %
# Precision  : 77.80 %
# F1 score   : 77.60 %
#
# ***** Epoch 44 of 100 *****
# Total Loss : 0.6224
# Accuracy   : 77.13 %
# Precision  : 77.58 %
# F1 score   : 77.06 %
#
# ***** Epoch 45 of 100 *****
# Total Loss : 0.5200
# Accuracy   : 78.05 %
# Precision  : 78.51 %
# F1 score   : 78.16 %
#
# ***** Epoch 46 of 100 *****
# Total Loss : 0.5858
# Accuracy   : 78.10 %
# Precision  : 78.03 %
# F1 score   : 77.91 %
#
# ***** Epoch 47 of 100 *****
# Total Loss : 0.5872
# Accuracy   : 77.60 %
# Precision  : 77.72 %
# F1 score   : 77.52 %
#
# ***** Epoch 48 of 100 *****
# Total Loss : 0.6225
# Accuracy   : 77.02 %
# Precision  : 77.89 %
# F1 score   : 76.86 %
#
# ***** Epoch 49 of 100 *****
# Total Loss : 0.5259
# Accuracy   : 76.94 %
# Precision  : 77.51 %
# F1 score   : 76.93 %
#
# ***** Epoch 50 of 100 *****
# Total Loss : 0.6708
# Accuracy   : 78.32 %
# Precision  : 78.73 %
# F1 score   : 78.41 %
#
# ***** Epoch 51 of 100 *****
# Total Loss : 0.7069
# Accuracy   : 77.77 %
# Precision  : 77.84 %
# F1 score   : 77.65 %
#
# ***** Epoch 52 of 100 *****
# Total Loss : 0.5993
# Accuracy   : 78.08 %
# Precision  : 78.91 %
# F1 score   : 78.35 %
#
# ***** Epoch 53 of 100 *****
# Total Loss : 0.5466
# Accuracy   : 78.37 %
# Precision  : 78.50 %
# F1 score   : 78.29 %
#
# ***** Epoch 54 of 100 *****
# Total Loss : 0.5925
# Accuracy   : 77.96 %
# Precision  : 78.38 %
# F1 score   : 77.98 %
#
# ***** Epoch 55 of 100 *****
# Total Loss : 0.5499
# Accuracy   : 77.86 %
# Precision  : 77.76 %
# F1 score   : 77.52 %
#
# ***** Epoch 56 of 100 *****
# Total Loss : 0.6042
# Accuracy   : 77.22 %
# Precision  : 78.01 %
# F1 score   : 77.05 %
#
# ***** Epoch 57 of 100 *****
# Total Loss : 0.7983
# Accuracy   : 76.35 %
# Precision  : 77.29 %
# F1 score   : 76.63 %
#
# ***** Epoch 58 of 100 *****
# Total Loss : 0.7218
# Accuracy   : 78.23 %
# Precision  : 78.31 %
# F1 score   : 78.11 %
#
# ***** Epoch 59 of 100 *****
# Total Loss : 0.7075
# Accuracy   : 77.57 %
# Precision  : 78.19 %
# F1 score   : 77.61 %
#
# ***** Epoch 60 of 100 *****
# Total Loss : 0.5551
# Accuracy   : 77.81 %
# Precision  : 77.81 %
# F1 score   : 77.55 %
#
# ***** Epoch 61 of 100 *****
# Total Loss : 0.6137
# Accuracy   : 78.78 %
# Precision  : 79.33 %
# F1 score   : 78.90 %
#
# ***** Epoch 62 of 100 *****
# Total Loss : 0.6355
# Accuracy   : 78.15 %
# Precision  : 78.15 %
# F1 score   : 77.77 %
#
# ***** Epoch 63 of 100 *****
# Total Loss : 0.7097
# Accuracy   : 78.59 %
# Precision  : 78.90 %
# F1 score   : 78.52 %
#
# ***** Epoch 64 of 100 *****
# Total Loss : 0.5195
# Accuracy   : 78.80 %
# Precision  : 79.26 %
# F1 score   : 78.90 %
#
# ***** Epoch 65 of 100 *****
# Total Loss : 0.7162
# Accuracy   : 78.47 %
# Precision  : 78.99 %
# F1 score   : 78.24 %
#
# ***** Epoch 66 of 100 *****
# Total Loss : 0.7902
# Accuracy   : 78.80 %
# Precision  : 79.14 %
# F1 score   : 78.84 %
#
# ***** Epoch 67 of 100 *****
# Total Loss : 0.5597
# Accuracy   : 79.19 %
# Precision  : 79.34 %
# F1 score   : 79.07 %
#
# ***** Epoch 68 of 100 *****
# Total Loss : 0.7856
# Accuracy   : 79.23 %
# Precision  : 79.21 %
# F1 score   : 79.13 %
#
# ***** Epoch 69 of 100 *****
# Total Loss : 0.7864
# Accuracy   : 77.99 %
# Precision  : 79.31 %
# F1 score   : 78.03 %
#
# ***** Epoch 70 of 100 *****
# Total Loss : 0.6876
# Accuracy   : 78.78 %
# Precision  : 79.71 %
# F1 score   : 78.82 %
#
# ***** Epoch 71 of 100 *****
# Total Loss : 0.8001
# Accuracy   : 79.38 %
# Precision  : 79.82 %
# F1 score   : 79.51 %
#
# ***** Epoch 72 of 100 *****
# Total Loss : 0.7320
# Accuracy   : 79.15 %
# Precision  : 79.54 %
# F1 score   : 79.23 %
#
# ***** Epoch 73 of 100 *****
# Total Loss : 0.8203
# Accuracy   : 79.39 %
# Precision  : 80.12 %
# F1 score   : 79.54 %
#
# ***** Epoch 74 of 100 *****
# Total Loss : 0.7864
# Accuracy   : 79.39 %
# Precision  : 79.72 %
# F1 score   : 79.48 %
#
# ***** Epoch 75 of 100 *****
# Total Loss : 0.6367
# Accuracy   : 79.49 %
# Precision  : 79.42 %
# F1 score   : 79.29 %
#
# ***** Epoch 76 of 100 *****
# Total Loss : 0.5954
# Accuracy   : 79.20 %
# Precision  : 79.35 %
# F1 score   : 79.08 %
#
# ***** Epoch 77 of 100 *****
# Total Loss : 0.5412
# Accuracy   : 78.93 %
# Precision  : 79.16 %
# F1 score   : 78.94 %
#
# ***** Epoch 78 of 100 *****
# Total Loss : 0.9891
# Accuracy   : 79.82 %
# Precision  : 80.04 %
# F1 score   : 79.82 %
#
# ***** Epoch 79 of 100 *****
# Total Loss : 0.7448
# Accuracy   : 79.03 %
# Precision  : 78.97 %
# F1 score   : 78.74 %
#
# ***** Epoch 80 of 100 *****
# Total Loss : 0.4684
# Accuracy   : 79.14 %
# Precision  : 79.59 %
# F1 score   : 79.21 %
#
# ***** Epoch 81 of 100 *****
# Total Loss : 0.7243
# Accuracy   : 79.85 %
# Precision  : 80.02 %
# F1 score   : 79.85 %
#
# ***** Epoch 82 of 100 *****
# Total Loss : 0.5997
# Accuracy   : 79.53 %
# Precision  : 79.67 %
# F1 score   : 79.46 %
#
# ***** Epoch 83 of 100 *****
# Total Loss : 0.6667
# Accuracy   : 79.52 %
# Precision  : 79.83 %
# F1 score   : 79.55 %
#
# ***** Epoch 84 of 100 *****
# Total Loss : 0.6256
# Accuracy   : 78.82 %
# Precision  : 79.32 %
# F1 score   : 78.83 %
#
# ***** Epoch 85 of 100 *****
# Total Loss : 0.7096
# Accuracy   : 79.45 %
# Precision  : 80.07 %
# F1 score   : 79.61 %
#
# ***** Epoch 86 of 100 *****
# Total Loss : 0.5214
# Accuracy   : 79.56 %
# Precision  : 79.66 %
# F1 score   : 79.47 %
#
# ***** Epoch 87 of 100 *****
# Total Loss : 0.4003
# Accuracy   : 77.71 %
# Precision  : 77.86 %
# F1 score   : 77.40 %
#
# ***** Epoch 88 of 100 *****
# Total Loss : 0.3601
# Accuracy   : 80.09 %
# Precision  : 80.00 %
# F1 score   : 79.85 %
#
# ***** Epoch 89 of 100 *****
# Total Loss : 0.4041
# Accuracy   : 78.85 %
# Precision  : 78.66 %
# F1 score   : 78.60 %
#
# ***** Epoch 90 of 100 *****
# Total Loss : 0.6683
# Accuracy   : 80.33 %
# Precision  : 80.75 %
# F1 score   : 80.31 %
#
# ***** Epoch 91 of 100 *****
# Total Loss : 0.4694
# Accuracy   : 80.34 %
# Precision  : 80.72 %
# F1 score   : 80.44 %
#
# ***** Epoch 92 of 100 *****
# Total Loss : 0.6622
# Accuracy   : 79.32 %
# Precision  : 79.49 %
# F1 score   : 79.03 %
#
# ***** Epoch 93 of 100 *****
# Total Loss : 0.5102
# Accuracy   : 79.23 %
# Precision  : 79.40 %
# F1 score   : 79.11 %
#
# ***** Epoch 94 of 100 *****
# Total Loss : 0.6390
# Accuracy   : 80.01 %
# Precision  : 80.24 %
# F1 score   : 79.89 %
#
# ***** Epoch 95 of 100 *****
# Total Loss : 0.5192
# Accuracy   : 80.10 %
# Precision  : 80.44 %
# F1 score   : 80.13 %
#
# ***** Epoch 96 of 100 *****
# Total Loss : 0.7753
# Accuracy   : 80.23 %
# Precision  : 80.34 %
# F1 score   : 80.21 %
#
# ***** Epoch 97 of 100 *****
# Total Loss : 0.8452
# Accuracy   : 80.59 %
# Precision  : 81.04 %
# F1 score   : 80.73 %
#
# ***** Epoch 98 of 100 *****
# Total Loss : 0.6998
# Accuracy   : 78.96 %
# Precision  : 79.18 %
# F1 score   : 78.88 %
#
# ***** Epoch 99 of 100 *****
# Total Loss : 0.7020
# Accuracy   : 80.07 %
# Precision  : 80.27 %
# F1 score   : 80.02 %
#
# ***** Epoch 100 of 100 *****
# Total Loss : 0.7175
# Accuracy   : 80.07 %
# Precision  : 80.67 %
# F1 score   : 80.21 %

# %%
model16 = cifar16_CNN(input_size=16).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model16.parameters(), lr=0.002)

results = train(
              model16,
              cifar_train_dataset16,
              criterion,
              optimizer,
              num_epochs = 50,
              batch_size = 512,
              verbose=True)

# saving the modle
torch.save(model16.state_dict(), f"./cifar_model16_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 50 *****
# Total Loss : 1.6193
# Accuracy   : 36.43 %
# Precision  : 35.81 %
# F1 score   : 34.01 %
#
# ***** Epoch 2 of 50 *****
# Total Loss : 1.5516
# Accuracy   : 41.90 %
# Precision  : 42.22 %
# F1 score   : 41.15 %
#
# ***** Epoch 3 of 50 *****
# Total Loss : 1.4723
# Accuracy   : 45.12 %
# Precision  : 44.39 %
# F1 score   : 44.23 %
#
# ***** Epoch 4 of 50 *****
# Total Loss : 1.4178
# Accuracy   : 47.05 %
# Precision  : 46.65 %
# F1 score   : 45.92 %
#
# ***** Epoch 5 of 50 *****
# Total Loss : 1.4159
# Accuracy   : 49.31 %
# Precision  : 48.67 %
# F1 score   : 48.57 %
#
# ***** Epoch 6 of 50 *****
# Total Loss : 1.4423
# Accuracy   : 50.70 %
# Precision  : 50.62 %
# F1 score   : 50.46 %
#
# ***** Epoch 7 of 50 *****
# Total Loss : 1.2863
# Accuracy   : 51.41 %
# Precision  : 50.69 %
# F1 score   : 50.34 %
#
# ***** Epoch 8 of 50 *****
# Total Loss : 1.1822
# Accuracy   : 52.87 %
# Precision  : 52.61 %
# F1 score   : 52.33 %
#
# ***** Epoch 9 of 50 *****
# Total Loss : 1.2990
# Accuracy   : 53.79 %
# Precision  : 54.18 %
# F1 score   : 53.66 %
#
# ***** Epoch 10 of 50 *****
# Total Loss : 1.2182
# Accuracy   : 52.79 %
# Precision  : 54.34 %
# F1 score   : 52.63 %
#
# ***** Epoch 11 of 50 *****
# Total Loss : 1.2923
# Accuracy   : 54.92 %
# Precision  : 54.32 %
# F1 score   : 54.31 %
#
# ***** Epoch 12 of 50 *****
# Total Loss : 1.1891
# Accuracy   : 54.64 %
# Precision  : 55.16 %
# F1 score   : 54.31 %
#
# ***** Epoch 13 of 50 *****
# Total Loss : 1.1989
# Accuracy   : 55.70 %
# Precision  : 56.31 %
# F1 score   : 55.53 %
#
# ***** Epoch 14 of 50 *****
# Total Loss : 1.2488
# Accuracy   : 56.62 %
# Precision  : 57.13 %
# F1 score   : 56.40 %
#
# ***** Epoch 15 of 50 *****
# Total Loss : 1.2262
# Accuracy   : 56.93 %
# Precision  : 57.40 %
# F1 score   : 56.90 %
#
# ***** Epoch 16 of 50 *****
# Total Loss : 1.2478
# Accuracy   : 57.19 %
# Precision  : 57.72 %
# F1 score   : 57.11 %
#
# ***** Epoch 17 of 50 *****
# Total Loss : 1.1674
# Accuracy   : 58.35 %
# Precision  : 57.91 %
# F1 score   : 57.87 %
#
# ***** Epoch 18 of 50 *****
# Total Loss : 1.0839
# Accuracy   : 58.04 %
# Precision  : 59.17 %
# F1 score   : 58.18 %
#
# ***** Epoch 19 of 50 *****
# Total Loss : 1.3099
# Accuracy   : 58.47 %
# Precision  : 59.24 %
# F1 score   : 58.57 %
#
# ***** Epoch 20 of 50 *****
# Total Loss : 1.2592
# Accuracy   : 59.28 %
# Precision  : 59.15 %
# F1 score   : 58.81 %
#
# ***** Epoch 21 of 50 *****
# Total Loss : 1.2556
# Accuracy   : 59.47 %
# Precision  : 59.32 %
# F1 score   : 59.01 %
#
# ***** Epoch 22 of 50 *****
# Total Loss : 1.1839
# Accuracy   : 60.21 %
# Precision  : 60.37 %
# F1 score   : 60.21 %
#
# ***** Epoch 23 of 50 *****
# Total Loss : 1.0879
# Accuracy   : 59.24 %
# Precision  : 59.41 %
# F1 score   : 58.94 %
#
# ***** Epoch 24 of 50 *****
# Total Loss : 1.1226
# Accuracy   : 59.78 %
# Precision  : 59.96 %
# F1 score   : 59.43 %
#
# ***** Epoch 25 of 50 *****
# Total Loss : 1.0663
# Accuracy   : 60.12 %
# Precision  : 60.42 %
# F1 score   : 59.97 %
#
# ***** Epoch 26 of 50 *****
# Total Loss : 1.0561
# Accuracy   : 61.09 %
# Precision  : 60.87 %
# F1 score   : 60.85 %
#
# ***** Epoch 27 of 50 *****
# Total Loss : 1.1930
# Accuracy   : 60.56 %
# Precision  : 60.71 %
# F1 score   : 60.44 %
#
# ***** Epoch 28 of 50 *****
# Total Loss : 1.0432
# Accuracy   : 61.02 %
# Precision  : 61.26 %
# F1 score   : 61.02 %
#
# ***** Epoch 29 of 50 *****
# Total Loss : 1.0631
# Accuracy   : 61.09 %
# Precision  : 61.28 %
# F1 score   : 61.04 %
#
# ***** Epoch 30 of 50 *****
# Total Loss : 1.0931
# Accuracy   : 61.40 %
# Precision  : 62.28 %
# F1 score   : 61.67 %
#
# ***** Epoch 31 of 50 *****
# Total Loss : 1.1244
# Accuracy   : 61.74 %
# Precision  : 61.74 %
# F1 score   : 61.60 %
#
# ***** Epoch 32 of 50 *****
# Total Loss : 1.0783
# Accuracy   : 61.79 %
# Precision  : 62.07 %
# F1 score   : 61.80 %
#
# ***** Epoch 33 of 50 *****
# Total Loss : 1.0112
# Accuracy   : 62.19 %
# Precision  : 62.05 %
# F1 score   : 62.08 %
#
# ***** Epoch 34 of 50 *****
# Total Loss : 1.0327
# Accuracy   : 61.92 %
# Precision  : 61.99 %
# F1 score   : 61.75 %
#
# ***** Epoch 35 of 50 *****
# Total Loss : 1.0601
# Accuracy   : 61.24 %
# Precision  : 61.31 %
# F1 score   : 60.81 %
#
# ***** Epoch 36 of 50 *****
# Total Loss : 0.9912
# Accuracy   : 62.28 %
# Precision  : 62.50 %
# F1 score   : 62.25 %
#
# ***** Epoch 37 of 50 *****
# Total Loss : 1.0487
# Accuracy   : 62.29 %
# Precision  : 62.56 %
# F1 score   : 62.14 %
#
# ***** Epoch 38 of 50 *****
# Total Loss : 1.0294
# Accuracy   : 61.92 %
# Precision  : 62.18 %
# F1 score   : 61.75 %
#
# ***** Epoch 39 of 50 *****
# Total Loss : 1.0617
# Accuracy   : 62.62 %
# Precision  : 62.61 %
# F1 score   : 62.39 %
#
# ***** Epoch 40 of 50 *****
# Total Loss : 0.9485
# Accuracy   : 62.52 %
# Precision  : 62.56 %
# F1 score   : 62.17 %
#
# ***** Epoch 41 of 50 *****
# Total Loss : 1.0387
# Accuracy   : 62.66 %
# Precision  : 62.67 %
# F1 score   : 62.40 %
#
# ***** Epoch 42 of 50 *****
# Total Loss : 1.0943
# Accuracy   : 62.67 %
# Precision  : 62.50 %
# F1 score   : 62.40 %
#
# ***** Epoch 43 of 50 *****
# Total Loss : 1.0500
# Accuracy   : 63.13 %
# Precision  : 63.50 %
# F1 score   : 63.24 %
#
# ***** Epoch 44 of 50 *****
# Total Loss : 1.1042
# Accuracy   : 63.04 %
# Precision  : 62.84 %
# F1 score   : 62.73 %
#
# ***** Epoch 45 of 50 *****
# Total Loss : 1.1835
# Accuracy   : 63.22 %
# Precision  : 62.97 %
# F1 score   : 62.91 %
#
# ***** Epoch 46 of 50 *****
# Total Loss : 1.1163
# Accuracy   : 63.03 %
# Precision  : 63.15 %
# F1 score   : 62.72 %
#
# ***** Epoch 47 of 50 *****
# Total Loss : 1.1224
# Accuracy   : 63.27 %
# Precision  : 63.80 %
# F1 score   : 63.44 %
#
# ***** Epoch 48 of 50 *****
# Total Loss : 1.0864
# Accuracy   : 63.10 %
# Precision  : 63.03 %
# F1 score   : 62.94 %
#
# ***** Epoch 49 of 50 *****
# Total Loss : 1.0562
# Accuracy   : 63.29 %
# Precision  : 62.95 %
# F1 score   : 62.87 %
#
# ***** Epoch 50 of 50 *****
# Total Loss : 1.0775
# Accuracy   : 63.51 %
# Precision  : 63.95 %
# F1 score   : 63.62 %

# %%
model8 = cifar8_CNN(input_size=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model8.parameters(), lr=0.002)

results = train(
              model8,
              cifar_train_dataset8,
              criterion,
              optimizer,
              num_epochs = 50,
              batch_size = 512,
              verbose=True)

# saving the modle
torch.save(model8.state_dict(), f"./cifar_model8_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 50 *****
# Total Loss : 1.8310
# Accuracy   : 34.64 %
# Precision  : 34.15 %
# F1 score   : 33.65 %
#
# ***** Epoch 2 of 50 *****
# Total Loss : 1.6567
# Accuracy   : 38.76 %
# Precision  : 38.71 %
# F1 score   : 37.65 %
#
# ***** Epoch 3 of 50 *****
# Total Loss : 1.6630
# Accuracy   : 41.23 %
# Precision  : 41.31 %
# F1 score   : 40.61 %
#
# ***** Epoch 4 of 50 *****
# Total Loss : 1.5393
# Accuracy   : 43.09 %
# Precision  : 42.93 %
# F1 score   : 42.11 %
#
# ***** Epoch 5 of 50 *****
# Total Loss : 1.5683
# Accuracy   : 44.56 %
# Precision  : 44.01 %
# F1 score   : 43.80 %
#
# ***** Epoch 6 of 50 *****
# Total Loss : 1.5659
# Accuracy   : 45.55 %
# Precision  : 45.62 %
# F1 score   : 44.98 %
#
# ***** Epoch 7 of 50 *****
# Total Loss : 1.5599
# Accuracy   : 46.16 %
# Precision  : 46.17 %
# F1 score   : 45.33 %
#
# ***** Epoch 8 of 50 *****
# Total Loss : 1.5793
# Accuracy   : 47.51 %
# Precision  : 46.97 %
# F1 score   : 46.62 %
#
# ***** Epoch 9 of 50 *****
# Total Loss : 1.4858
# Accuracy   : 47.73 %
# Precision  : 47.34 %
# F1 score   : 47.12 %
#
# ***** Epoch 10 of 50 *****
# Total Loss : 1.4827
# Accuracy   : 48.09 %
# Precision  : 47.49 %
# F1 score   : 47.26 %
#
# ***** Epoch 11 of 50 *****
# Total Loss : 1.5118
# Accuracy   : 48.55 %
# Precision  : 49.57 %
# F1 score   : 48.82 %
#
# ***** Epoch 12 of 50 *****
# Total Loss : 1.3974
# Accuracy   : 49.19 %
# Precision  : 48.63 %
# F1 score   : 48.29 %
#
# ***** Epoch 13 of 50 *****
# Total Loss : 1.3570
# Accuracy   : 49.59 %
# Precision  : 49.25 %
# F1 score   : 49.02 %
#
# ***** Epoch 14 of 50 *****
# Total Loss : 1.4461
# Accuracy   : 49.67 %
# Precision  : 49.48 %
# F1 score   : 49.32 %
#
# ***** Epoch 15 of 50 *****
# Total Loss : 1.3794
# Accuracy   : 49.78 %
# Precision  : 50.23 %
# F1 score   : 49.66 %
#
# ***** Epoch 16 of 50 *****
# Total Loss : 1.4038
# Accuracy   : 50.32 %
# Precision  : 50.07 %
# F1 score   : 49.94 %
#
# ***** Epoch 17 of 50 *****
# Total Loss : 1.3926
# Accuracy   : 50.68 %
# Precision  : 49.77 %
# F1 score   : 49.97 %
#
# ***** Epoch 18 of 50 *****
# Total Loss : 1.5386
# Accuracy   : 50.92 %
# Precision  : 51.17 %
# F1 score   : 50.83 %
#
# ***** Epoch 19 of 50 *****
# Total Loss : 1.3421
# Accuracy   : 51.35 %
# Precision  : 51.36 %
# F1 score   : 50.96 %
#
# ***** Epoch 20 of 50 *****
# Total Loss : 1.3489
# Accuracy   : 51.48 %
# Precision  : 51.05 %
# F1 score   : 51.04 %
#
# ***** Epoch 21 of 50 *****
# Total Loss : 1.4544
# Accuracy   : 51.63 %
# Precision  : 51.01 %
# F1 score   : 50.87 %
#
# ***** Epoch 22 of 50 *****
# Total Loss : 1.3561
# Accuracy   : 52.31 %
# Precision  : 51.61 %
# F1 score   : 51.59 %
#
# ***** Epoch 23 of 50 *****
# Total Loss : 1.3083
# Accuracy   : 51.97 %
# Precision  : 51.75 %
# F1 score   : 51.39 %
#
# ***** Epoch 24 of 50 *****
# Total Loss : 1.4727
# Accuracy   : 52.11 %
# Precision  : 51.69 %
# F1 score   : 51.19 %
#
# ***** Epoch 25 of 50 *****
# Total Loss : 1.3288
# Accuracy   : 52.47 %
# Precision  : 52.25 %
# F1 score   : 51.99 %
#
# ***** Epoch 26 of 50 *****
# Total Loss : 1.3388
# Accuracy   : 52.44 %
# Precision  : 53.01 %
# F1 score   : 52.29 %
#
# ***** Epoch 27 of 50 *****
# Total Loss : 1.4810
# Accuracy   : 52.79 %
# Precision  : 52.49 %
# F1 score   : 52.42 %
#
# ***** Epoch 28 of 50 *****
# Total Loss : 1.2417
# Accuracy   : 53.16 %
# Precision  : 52.99 %
# F1 score   : 52.72 %
#
# ***** Epoch 29 of 50 *****
# Total Loss : 1.2906
# Accuracy   : 52.84 %
# Precision  : 53.04 %
# F1 score   : 52.45 %
#
# ***** Epoch 30 of 50 *****
# Total Loss : 1.2981
# Accuracy   : 52.84 %
# Precision  : 52.84 %
# F1 score   : 52.48 %
#
# ***** Epoch 31 of 50 *****
# Total Loss : 1.2637
# Accuracy   : 53.54 %
# Precision  : 53.65 %
# F1 score   : 53.40 %
#
# ***** Epoch 32 of 50 *****
# Total Loss : 1.3226
# Accuracy   : 53.55 %
# Precision  : 53.41 %
# F1 score   : 53.31 %
#
# ***** Epoch 33 of 50 *****
# Total Loss : 1.2619
# Accuracy   : 53.54 %
# Precision  : 53.97 %
# F1 score   : 53.54 %
#
# ***** Epoch 34 of 50 *****
# Total Loss : 1.3686
# Accuracy   : 53.02 %
# Precision  : 52.30 %
# F1 score   : 52.15 %
#
# ***** Epoch 35 of 50 *****
# Total Loss : 1.1497
# Accuracy   : 53.95 %
# Precision  : 53.42 %
# F1 score   : 53.49 %
#
# ***** Epoch 36 of 50 *****
# Total Loss : 1.3065
# Accuracy   : 53.72 %
# Precision  : 53.75 %
# F1 score   : 53.51 %
#
# ***** Epoch 37 of 50 *****
# Total Loss : 1.2394
# Accuracy   : 53.85 %
# Precision  : 53.61 %
# F1 score   : 53.44 %
#
# ***** Epoch 38 of 50 *****
# Total Loss : 1.3299
# Accuracy   : 53.90 %
# Precision  : 53.90 %
# F1 score   : 53.68 %
#
# ***** Epoch 39 of 50 *****
# Total Loss : 1.3737
# Accuracy   : 54.11 %
# Precision  : 53.87 %
# F1 score   : 53.51 %
#
# ***** Epoch 40 of 50 *****
# Total Loss : 1.3806
# Accuracy   : 53.89 %
# Precision  : 53.64 %
# F1 score   : 53.27 %
#
# ***** Epoch 41 of 50 *****
# Total Loss : 1.2624
# Accuracy   : 54.36 %
# Precision  : 54.25 %
# F1 score   : 53.96 %
#
# ***** Epoch 42 of 50 *****
# Total Loss : 1.2364
# Accuracy   : 54.53 %
# Precision  : 54.29 %
# F1 score   : 54.20 %
#
# ***** Epoch 43 of 50 *****
# Total Loss : 1.2232
# Accuracy   : 54.48 %
# Precision  : 54.01 %
# F1 score   : 54.04 %
#
# ***** Epoch 44 of 50 *****
# Total Loss : 1.3179
# Accuracy   : 54.12 %
# Precision  : 54.59 %
# F1 score   : 53.88 %
#
# ***** Epoch 45 of 50 *****
# Total Loss : 1.2294
# Accuracy   : 54.20 %
# Precision  : 53.76 %
# F1 score   : 53.69 %
#
# ***** Epoch 46 of 50 *****
# Total Loss : 1.3529
# Accuracy   : 54.66 %
# Precision  : 54.63 %
# F1 score   : 54.39 %
#
# ***** Epoch 47 of 50 *****
# Total Loss : 1.2731
# Accuracy   : 54.92 %
# Precision  : 54.90 %
# F1 score   : 54.59 %
#
# ***** Epoch 48 of 50 *****
# Total Loss : 1.4036
# Accuracy   : 54.27 %
# Precision  : 53.88 %
# F1 score   : 53.73 %
#
# ***** Epoch 49 of 50 *****
# Total Loss : 1.2291
# Accuracy   : 54.59 %
# Precision  : 54.55 %
# F1 score   : 54.27 %
#
# ***** Epoch 50 of 50 *****
# Total Loss : 1.3226
# Accuracy   : 55.43 %
# Precision  : 55.45 %
# F1 score   : 55.22 %

# %% [markdown]
# ### Test
# Now testing the three model with two strategies:
# 1. TOTV
# 2. TVTV

# %% [markdown]
# #### 1. Train with **TOTV** method
# In this method we train on original dataset and test on varying dataset

# %% [markdown]
# #### 2. Train with **TVTV** method
# In this method we train and test on each varying dataset

# %%
test(model32, cifar_test_dataset32, 512, verbose=True)
# Out:
# Accuracy: 0.71, Precision: 0.72, F1 Score: 0.72
# (0.714900016784668, 0.7224754095077515, 0.7169740796089172)

# %%
test(model16, cifar_test_dataset16, 512, verbose=True)
# Out:
# Accuracy: 0.59, Precision: 0.59, F1 Score: 0.59
# (0.5891000032424927, 0.5932396650314331, 0.5901081562042236)

# %%
test(model8, cifar_test_dataset8, 512, verbose=True)
# Out:
# Accuracy: 0.52, Precision: 0.52, F1 Score: 0.52
# (0.5177000164985657, 0.5177978873252869, 0.515409529209137)

# %% [markdown]
# ## 2. Introduction to **CNN**

# %% [markdown]
# ### Load dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
train_dataset = torchvision.datasets.FashionMNIST(root="./data", train=True,
                                                  download=True, transform=transform)
test_dataset = torchvision.datasets.FashionMNIST(root="./data", train=False,
                                                  download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size = 16,
                                           shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset,
                                           batch_size = 16,
                                           shuffle=True)

# %%
classes = train_dataset.classes

# %% [markdown]
# First see some examples of dataset

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
show_image(torchvision.utils.make_grid(images))
labels_name = show_labels(labels)
top_half = labels_name[:8]
bottom_half = labels_name[8:]
print(top_half)
print(bottom_half)
# Out:
# ['Bag', 'Shirt', 'Trouser', 'Trouser', 'Pullover', 'Trouser', 'Trouser', 'Shirt']
# ['Pullover', 'Pullover', 'Coat', 'Shirt', 'Sandal', 'Trouser', 'Sneaker', 'Sandal']

# %% [markdown]
# ### Make two different CNN architecture

# %% [markdown]
# First architecture is the **first** architecture that introduced in the **"CNN Model for Image Classification on MNIST and Fashion-MNIST Datast"** paper

# %%
class CNN1(nn.Module):

  def __init__(self):
    super().__init__()
    
    self.fc1 = nn.Linear(28*28, 128)
    self.fc2 = nn.Linear(128, 10)
    self.dropout = nn.Dropout(0.2)
    

  def forward(self, x):
    x =  x.view(-1, 28*28)
    x = F.relu(self.fc1(x))
    x = self.dropout(self.fc2(x))
    return x

# %% [markdown]
# Second selected architecture is the **fifth** architecture from the paper

# %%
class CNN2(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(1, 32, 3)    # input: 28*28 
    self.conv2 = nn.Conv2d(32, 32, 3)   # input: 26*26
    self.pool1 = nn.MaxPool2d(2, 2)     # input: 24*24
    self.dropout1 = nn.Dropout(0.25)
    self.conv3 = nn.Conv2d(32, 64, 3)   # input: 12*12
    self.conv4 = nn.Conv2d(64, 64, 3)   # input: 10*10
    self.pool2 = nn.MaxPool2d(2,2)      # input: 8*8
    self.dropout2 = nn.Dropout(0.25)
    self.fc1 = nn.Linear(64*4*4, 512)   # input: 4*4
    self.dropout3 = nn.Dropout(0.5)
    self.fc2 = nn.Linear(512, 10)
    

  def forward(self, x):
    
    # conv1
    x = F.relu(self.conv1(x))

    # conv2
    x = F.relu(self.conv2(x))
    x = self.dropout1(self.pool1(x))

    # conv3
    x = F.relu(self.conv3(x))

    # conv 4
    x = F.relu(self.conv4(x))
    x = self.dropout2(self.pool2(x))

    # fully connected layers
    x = x.view(-1, 64*4*4)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    

    return x

# %% [markdown]
# ### Training

# %% [markdown]
# First define a function `train` which will be use for training each model with desired parameters

# %% [markdown]
# #### 1. First architecture

# %%
model1 = CNN1().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model1.parameters(), lr=0.002)

results = train(
              model1,
              train_dataset,
              criterion,
              optimizer,
              num_epochs = 100,
              batch_size = 64,
              verbose=True)

# saving the model
torch.save(model1.state_dict(), f"./model1_{results['accuracy']}")
# Out:
# ***** Epoch 1 of 100 *****
# Total Loss : 0.6075
# Accuracy   : 73.87 %
# Precision  : 76.28 %
# F1 score   : 73.73 %
#
# ***** Epoch 2 of 100 *****
# Total Loss : 0.8600
# Accuracy   : 77.14 %
# Precision  : 78.29 %
# F1 score   : 77.20 %
#
# ***** Epoch 3 of 100 *****
# Total Loss : 0.5958
# Accuracy   : 77.50 %
# Precision  : 79.02 %
# F1 score   : 77.65 %
#
# ***** Epoch 4 of 100 *****
# Total Loss : 0.6373
# Accuracy   : 77.73 %
# Precision  : 79.37 %
# F1 score   : 77.94 %
#
# ***** Epoch 5 of 100 *****
# Total Loss : 0.4103
# Accuracy   : 78.10 %
# Precision  : 79.96 %
# F1 score   : 78.27 %
#
# ***** Epoch 6 of 100 *****
# Total Loss : 0.8433
# Accuracy   : 78.34 %
# Precision  : 79.73 %
# F1 score   : 78.68 %
#
# ***** Epoch 7 of 100 *****
# Total Loss : 0.2075
# Accuracy   : 79.33 %
# Precision  : 80.68 %
# F1 score   : 79.66 %
#
# ***** Epoch 8 of 100 *****
# Total Loss : 0.5965
# Accuracy   : 79.42 %
# Precision  : 80.87 %
# F1 score   : 79.64 %
#
# ***** Epoch 9 of 100 *****
# Total Loss : 0.3194
# Accuracy   : 79.69 %
# Precision  : 80.83 %
# F1 score   : 79.92 %
#
# ***** Epoch 10 of 100 *****
# Total Loss : 0.5162
# Accuracy   : 80.18 %
# Precision  : 81.31 %
# F1 score   : 80.37 %
#
# ***** Epoch 11 of 100 *****
# Total Loss : 0.5289
# Accuracy   : 79.72 %
# Precision  : 80.90 %
# F1 score   : 80.01 %
#
# ***** Epoch 12 of 100 *****
# Total Loss : 0.7667
# Accuracy   : 79.65 %
# Precision  : 81.05 %
# F1 score   : 79.84 %
#
# ***** Epoch 13 of 100 *****
# Total Loss : 0.4156
# Accuracy   : 80.61 %
# Precision  : 81.93 %
# F1 score   : 80.76 %
#
# ***** Epoch 14 of 100 *****
# Total Loss : 0.4626
# Accuracy   : 80.34 %
# Precision  : 82.09 %
# F1 score   : 80.38 %
#
# ***** Epoch 15 of 100 *****
# Total Loss : 0.4921
# Accuracy   : 80.22 %
# Precision  : 81.72 %
# F1 score   : 80.58 %
#
# ***** Epoch 16 of 100 *****
# Total Loss : 0.5084
# Accuracy   : 80.66 %
# Precision  : 82.14 %
# F1 score   : 81.01 %
#
# ***** Epoch 17 of 100 *****
# Total Loss : 0.4177
# Accuracy   : 80.77 %
# Precision  : 82.44 %
# F1 score   : 80.99 %
#
# ***** Epoch 18 of 100 *****
# Total Loss : 0.3599
# Accuracy   : 81.18 %
# Precision  : 82.58 %
# F1 score   : 81.50 %
#
# ***** Epoch 19 of 100 *****
# Total Loss : 0.4399
# Accuracy   : 81.11 %
# Precision  : 82.56 %
# F1 score   : 81.43 %
#
# ***** Epoch 20 of 100 *****
# Total Loss : 0.5149
# Accuracy   : 81.14 %
# Precision  : 82.60 %
# F1 score   : 81.36 %
#
# ***** Epoch 21 of 100 *****
# Total Loss : 0.1069
# Accuracy   : 81.79 %
# Precision  : 83.28 %
# F1 score   : 82.07 %
#
# ***** Epoch 22 of 100 *****
# Total Loss : 0.1570
# Accuracy   : 81.81 %
# Precision  : 83.20 %
# F1 score   : 82.03 %
#
# ***** Epoch 23 of 100 *****
# Total Loss : 0.4236
# Accuracy   : 81.91 %
# Precision  : 83.24 %
# F1 score   : 82.17 %
#
# ***** Epoch 24 of 100 *****
# Total Loss : 0.7390
# Accuracy   : 82.16 %
# Precision  : 83.54 %
# F1 score   : 82.41 %
#
# ***** Epoch 25 of 100 *****
# Total Loss : 0.5882
# Accuracy   : 81.95 %
# Precision  : 83.28 %
# F1 score   : 82.20 %
#
# ***** Epoch 26 of 100 *****
# Total Loss : 0.3796
# Accuracy   : 82.42 %
# Precision  : 83.65 %
# F1 score   : 82.65 %
#
# ***** Epoch 27 of 100 *****
# Total Loss : 0.6782
# Accuracy   : 81.08 %
# Precision  : 83.40 %
# F1 score   : 81.23 %
#
# ***** Epoch 28 of 100 *****
# Total Loss : 0.2532
# Accuracy   : 82.15 %
# Precision  : 83.82 %
# F1 score   : 82.36 %
#
# ***** Epoch 29 of 100 *****
# Total Loss : 0.4256
# Accuracy   : 82.16 %
# Precision  : 83.67 %
# F1 score   : 82.37 %
#
# ***** Epoch 30 of 100 *****
# Total Loss : 0.5452
# Accuracy   : 82.70 %
# Precision  : 83.95 %
# F1 score   : 82.91 %
#
# ***** Epoch 31 of 100 *****
# Total Loss : 0.3434
# Accuracy   : 82.58 %
# Precision  : 84.21 %
# F1 score   : 82.75 %
#
# ***** Epoch 32 of 100 *****
# Total Loss : 0.4897
# Accuracy   : 82.48 %
# Precision  : 83.95 %
# F1 score   : 82.65 %
#
# ***** Epoch 33 of 100 *****
# Total Loss : 0.4765
# Accuracy   : 82.89 %
# Precision  : 84.32 %
# F1 score   : 83.12 %
#
# ***** Epoch 34 of 100 *****
# Total Loss : 0.3340
# Accuracy   : 83.11 %
# Precision  : 84.37 %
# F1 score   : 83.29 %
#
# ***** Epoch 35 of 100 *****
# Total Loss : 0.3920
# Accuracy   : 83.29 %
# Precision  : 84.52 %
# F1 score   : 83.54 %
#
# ***** Epoch 36 of 100 *****
# Total Loss : 0.3631
# Accuracy   : 83.53 %
# Precision  : 85.11 %
# F1 score   : 83.71 %
#
# ***** Epoch 37 of 100 *****
# Total Loss : 0.5325
# Accuracy   : 83.23 %
# Precision  : 84.66 %
# F1 score   : 83.42 %
#
# ***** Epoch 38 of 100 *****
# Total Loss : 0.4914
# Accuracy   : 83.54 %
# Precision  : 84.86 %
# F1 score   : 83.74 %
#
# ***** Epoch 39 of 100 *****
# Total Loss : 0.3240
# Accuracy   : 83.35 %
# Precision  : 84.89 %
# F1 score   : 83.54 %
#
# ***** Epoch 40 of 100 *****
# Total Loss : 0.5819
# Accuracy   : 83.38 %
# Precision  : 84.58 %
# F1 score   : 83.60 %
#
# ***** Epoch 41 of 100 *****
# Total Loss : 0.2811
# Accuracy   : 83.24 %
# Precision  : 84.64 %
# F1 score   : 83.46 %
#
# ***** Epoch 42 of 100 *****
# Total Loss : 0.4439
# Accuracy   : 83.49 %
# Precision  : 84.88 %
# F1 score   : 83.69 %
#
# ***** Epoch 43 of 100 *****
# Total Loss : 0.2927
# Accuracy   : 83.67 %
# Precision  : 84.92 %
# F1 score   : 83.90 %
#
# ***** Epoch 44 of 100 *****
# Total Loss : 0.4827
# Accuracy   : 83.27 %
# Precision  : 84.49 %
# F1 score   : 83.48 %
#
# ***** Epoch 45 of 100 *****
# Total Loss : 0.1908
# Accuracy   : 84.20 %
# Precision  : 85.58 %
# F1 score   : 84.42 %
#
# ***** Epoch 46 of 100 *****
# Total Loss : 0.4573
# Accuracy   : 83.25 %
# Precision  : 84.41 %
# F1 score   : 83.49 %
#
# ***** Epoch 47 of 100 *****
# Total Loss : 0.2505
# Accuracy   : 83.85 %
# Precision  : 85.53 %
# F1 score   : 84.06 %
#
# ***** Epoch 48 of 100 *****
# Total Loss : 0.3628
# Accuracy   : 83.53 %
# Precision  : 84.90 %
# F1 score   : 83.81 %
#
# ***** Epoch 49 of 100 *****
# Total Loss : 0.2981
# Accuracy   : 84.38 %
# Precision  : 85.83 %
# F1 score   : 84.59 %
#
# ***** Epoch 50 of 100 *****
# Total Loss : 0.6486
# Accuracy   : 83.82 %
# Precision  : 84.98 %
# F1 score   : 84.02 %
#
# ***** Epoch 51 of 100 *****
# Total Loss : 0.4600
# Accuracy   : 83.93 %
# Precision  : 85.20 %
# F1 score   : 84.17 %
#
# ***** Epoch 52 of 100 *****
# Total Loss : 0.3498
# Accuracy   : 84.42 %
# Precision  : 85.73 %
# F1 score   : 84.64 %
#
# ***** Epoch 53 of 100 *****
# Total Loss : 0.1332
# Accuracy   : 83.65 %
# Precision  : 85.10 %
# F1 score   : 83.92 %
#
# ***** Epoch 54 of 100 *****
# Total Loss : 0.4790
# Accuracy   : 84.38 %
# Precision  : 85.77 %
# F1 score   : 84.59 %
#
# ***** Epoch 55 of 100 *****
# Total Loss : 0.3242
# Accuracy   : 84.24 %
# Precision  : 85.50 %
# F1 score   : 84.46 %
#
# ***** Epoch 56 of 100 *****
# Total Loss : 0.2205
# Accuracy   : 84.41 %
# Precision  : 85.94 %
# F1 score   : 84.62 %
#
# ***** Epoch 57 of 100 *****
# Total Loss : 0.2906
# Accuracy   : 84.48 %
# Precision  : 86.01 %
# F1 score   : 84.68 %
#
# ***** Epoch 58 of 100 *****
# Total Loss : 0.6072
# Accuracy   : 83.79 %
# Precision  : 85.35 %
# F1 score   : 83.99 %
#
# ***** Epoch 59 of 100 *****
# Total Loss : 0.5774
# Accuracy   : 84.30 %
# Precision  : 85.84 %
# F1 score   : 84.50 %
#
# ***** Epoch 60 of 100 *****
# Total Loss : 0.1616
# Accuracy   : 84.90 %
# Precision  : 86.26 %
# F1 score   : 85.09 %
#
# ***** Epoch 61 of 100 *****
# Total Loss : 0.1720
# Accuracy   : 84.29 %
# Precision  : 85.80 %
# F1 score   : 84.49 %
#
# ***** Epoch 62 of 100 *****
# Total Loss : 0.2406
# Accuracy   : 84.30 %
# Precision  : 85.91 %
# F1 score   : 84.48 %
#
# ***** Epoch 63 of 100 *****
# Total Loss : 0.3044
# Accuracy   : 84.70 %
# Precision  : 86.13 %
# F1 score   : 84.88 %
#
# ***** Epoch 64 of 100 *****
# Total Loss : 0.2573
# Accuracy   : 84.15 %
# Precision  : 85.80 %
# F1 score   : 84.35 %
#
# ***** Epoch 65 of 100 *****
# Total Loss : 0.2932
# Accuracy   : 84.41 %
# Precision  : 85.99 %
# F1 score   : 84.61 %
#
# ***** Epoch 66 of 100 *****
# Total Loss : 0.2479
# Accuracy   : 85.14 %
# Precision  : 86.51 %
# F1 score   : 85.34 %
#
# ***** Epoch 67 of 100 *****
# Total Loss : 0.1641
# Accuracy   : 84.53 %
# Precision  : 85.98 %
# F1 score   : 84.76 %
#
# ***** Epoch 68 of 100 *****
# Total Loss : 0.6182
# Accuracy   : 84.22 %
# Precision  : 85.71 %
# F1 score   : 84.46 %
#
# ***** Epoch 69 of 100 *****
# Total Loss : 0.2753
# Accuracy   : 84.83 %
# Precision  : 86.21 %
# F1 score   : 85.07 %
#
# ***** Epoch 70 of 100 *****
# Total Loss : 0.4176
# Accuracy   : 84.94 %
# Precision  : 86.36 %
# F1 score   : 85.14 %
#
# ***** Epoch 71 of 100 *****
# Total Loss : 0.3199
# Accuracy   : 84.78 %
# Precision  : 86.14 %
# F1 score   : 84.97 %
#
# ***** Epoch 72 of 100 *****
# Total Loss : 0.4308
# Accuracy   : 84.25 %
# Precision  : 85.42 %
# F1 score   : 84.47 %
#
# ***** Epoch 73 of 100 *****
# Total Loss : 0.3043
# Accuracy   : 84.40 %
# Precision  : 86.00 %
# F1 score   : 84.61 %
#
# ***** Epoch 74 of 100 *****
# Total Loss : 0.3618
# Accuracy   : 85.08 %
# Precision  : 86.57 %
# F1 score   : 85.29 %
#
# ***** Epoch 75 of 100 *****
# Total Loss : 0.1667
# Accuracy   : 85.04 %
# Precision  : 86.32 %
# F1 score   : 85.25 %
#
# ***** Epoch 76 of 100 *****
# Total Loss : 0.4037
# Accuracy   : 84.77 %
# Precision  : 86.32 %
# F1 score   : 84.99 %
#
# ***** Epoch 77 of 100 *****
# Total Loss : 0.3141
# Accuracy   : 85.23 %
# Precision  : 86.56 %
# F1 score   : 85.44 %
#
# ***** Epoch 78 of 100 *****
# Total Loss : 0.3551
# Accuracy   : 85.03 %
# Precision  : 86.44 %
# F1 score   : 85.26 %
#
# ***** Epoch 79 of 100 *****
# Total Loss : 0.1472
# Accuracy   : 84.72 %
# Precision  : 86.09 %
# F1 score   : 84.95 %
#
# ***** Epoch 80 of 100 *****
# Total Loss : 0.3502
# Accuracy   : 85.45 %
# Precision  : 86.73 %
# F1 score   : 85.64 %
#
# ***** Epoch 81 of 100 *****
# Total Loss : 0.2685
# Accuracy   : 85.31 %
# Precision  : 86.73 %
# F1 score   : 85.51 %
#
# ***** Epoch 82 of 100 *****
# Total Loss : 0.2387
# Accuracy   : 84.87 %
# Precision  : 86.31 %
# F1 score   : 85.07 %
#
# ***** Epoch 83 of 100 *****
# Total Loss : 0.1342
# Accuracy   : 85.34 %
# Precision  : 86.62 %
# F1 score   : 85.54 %
#
# ***** Epoch 84 of 100 *****
# Total Loss : 0.6413
# Accuracy   : 84.91 %
# Precision  : 86.20 %
# F1 score   : 85.12 %
#
# ***** Epoch 85 of 100 *****
# Total Loss : 0.2425
# Accuracy   : 85.83 %
# Precision  : 87.16 %
# F1 score   : 86.03 %
#
# ***** Epoch 86 of 100 *****
# Total Loss : 0.2674
# Accuracy   : 85.50 %
# Precision  : 86.76 %
# F1 score   : 85.70 %
#
# ***** Epoch 87 of 100 *****
# Total Loss : 0.1480
# Accuracy   : 84.98 %
# Precision  : 86.32 %
# F1 score   : 85.18 %
#
# ***** Epoch 88 of 100 *****
# Total Loss : 0.4301
# Accuracy   : 84.75 %
# Precision  : 86.53 %
# F1 score   : 84.99 %
#
# ***** Epoch 89 of 100 *****
# Total Loss : 0.2879
# Accuracy   : 85.71 %
# Precision  : 87.20 %
# F1 score   : 85.90 %
#
# ***** Epoch 90 of 100 *****
# Total Loss : 0.4452
# Accuracy   : 85.42 %
# Precision  : 86.86 %
# F1 score   : 85.63 %
#
# ***** Epoch 91 of 100 *****
# Total Loss : 0.3564
# Accuracy   : 85.10 %
# Precision  : 86.59 %
# F1 score   : 85.29 %
#
# ***** Epoch 92 of 100 *****
# Total Loss : 0.2453
# Accuracy   : 86.13 %
# Precision  : 87.45 %
# F1 score   : 86.30 %
#
# ***** Epoch 93 of 100 *****
# Total Loss : 0.3856
# Accuracy   : 85.40 %
# Precision  : 86.64 %
# F1 score   : 85.60 %
#
# ***** Epoch 94 of 100 *****
# Total Loss : 0.3235
# Accuracy   : 85.56 %
# Precision  : 86.94 %
# F1 score   : 85.75 %
#
# ***** Epoch 95 of 100 *****
# Total Loss : 0.0933
# Accuracy   : 85.61 %
# Precision  : 86.83 %
# F1 score   : 85.81 %
#
# ***** Epoch 96 of 100 *****
# Total Loss : 0.3504
# Accuracy   : 85.22 %
# Precision  : 86.51 %
# F1 score   : 85.41 %
#
# ***** Epoch 97 of 100 *****
# Total Loss : 0.4627
# Accuracy   : 85.57 %
# Precision  : 86.90 %
# F1 score   : 85.75 %
#
# ***** Epoch 98 of 100 *****
# Total Loss : 0.3172
# Accuracy   : 85.91 %
# Precision  : 87.24 %
# F1 score   : 86.09 %
#
# ***** Epoch 99 of 100 *****
# Total Loss : 0.3752
# Accuracy   : 85.37 %
# Precision  : 86.74 %
# F1 score   : 85.57 %
#
# ***** Epoch 100 of 100 *****
# Total Loss : 0.2055
# Accuracy   : 85.15 %
# Precision  : 86.54 %
# F1 score   : 85.37 %

# %%
plt.plot(results['accuracy'], label="accuracy")
plt.plot(results['precision'], label="precision")
plt.plot(results['f1_score'], label="f1 score")
plt.legend()
plt.show()

# %% [markdown]
# #### 2. Second architecture

# %%
model2 = CNN2().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(model2.parameters(), lr=0.002)

results = train(
              model2,
              train_dataset,
              criterion,
              optimizer,
              num_epochs = 50,
              batch_size = 128,
              verbose=True)

# saving the modle
torch.save(model2.state_dict(), f"./model2_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 50 *****
# Total Loss : 0.5842
# Accuracy   : 76.88 %
# Precision  : 81.84 %
# F1 score   : 76.89 %
#
# ***** Epoch 2 of 50 *****
# Total Loss : 0.4037
# Accuracy   : 84.32 %
# Precision  : 84.62 %
# F1 score   : 83.96 %
#
# ***** Epoch 3 of 50 *****
# Total Loss : 0.2090
# Accuracy   : 87.01 %
# Precision  : 86.88 %
# F1 score   : 86.81 %
#
# ***** Epoch 4 of 50 *****
# Total Loss : 0.3564
# Accuracy   : 88.26 %
# Precision  : 88.33 %
# F1 score   : 87.92 %
#
# ***** Epoch 5 of 50 *****
# Total Loss : 0.4191
# Accuracy   : 88.03 %
# Precision  : 89.17 %
# F1 score   : 88.23 %
#
# ***** Epoch 6 of 50 *****
# Total Loss : 0.2153
# Accuracy   : 89.95 %
# Precision  : 90.05 %
# F1 score   : 89.82 %
#
# ***** Epoch 7 of 50 *****
# Total Loss : 0.2865
# Accuracy   : 90.55 %
# Precision  : 90.78 %
# F1 score   : 90.62 %
#
# ***** Epoch 8 of 50 *****
# Total Loss : 0.1666
# Accuracy   : 91.11 %
# Precision  : 91.15 %
# F1 score   : 91.00 %
#
# ***** Epoch 9 of 50 *****
# Total Loss : 0.1665
# Accuracy   : 90.91 %
# Precision  : 91.19 %
# F1 score   : 90.86 %
#
# ***** Epoch 10 of 50 *****
# Total Loss : 0.1695
# Accuracy   : 90.56 %
# Precision  : 90.88 %
# F1 score   : 90.51 %
#
# ***** Epoch 11 of 50 *****
# Total Loss : 0.2116
# Accuracy   : 91.36 %
# Precision  : 91.65 %
# F1 score   : 91.17 %
#
# ***** Epoch 12 of 50 *****
# Total Loss : 0.1612
# Accuracy   : 92.49 %
# Precision  : 92.54 %
# F1 score   : 92.34 %
#
# ***** Epoch 13 of 50 *****
# Total Loss : 0.2001
# Accuracy   : 92.61 %
# Precision  : 92.68 %
# F1 score   : 92.47 %
#
# ***** Epoch 14 of 50 *****
# Total Loss : 0.2280
# Accuracy   : 92.80 %
# Precision  : 93.02 %
# F1 score   : 92.86 %
#
# ***** Epoch 15 of 50 *****
# Total Loss : 0.2497
# Accuracy   : 92.73 %
# Precision  : 92.95 %
# F1 score   : 92.79 %
#
# ***** Epoch 16 of 50 *****
# Total Loss : 0.0942
# Accuracy   : 92.98 %
# Precision  : 93.08 %
# F1 score   : 92.97 %
#
# ***** Epoch 17 of 50 *****
# Total Loss : 0.2205
# Accuracy   : 93.65 %
# Precision  : 93.63 %
# F1 score   : 93.63 %
#
# ***** Epoch 18 of 50 *****
# Total Loss : 0.2430
# Accuracy   : 93.42 %
# Precision  : 93.39 %
# F1 score   : 93.36 %
#
# ***** Epoch 19 of 50 *****
# Total Loss : 0.2860
# Accuracy   : 93.36 %
# Precision  : 93.44 %
# F1 score   : 93.32 %
#
# ***** Epoch 20 of 50 *****
# Total Loss : 0.1239
# Accuracy   : 93.89 %
# Precision  : 93.92 %
# F1 score   : 93.88 %
#
# ***** Epoch 21 of 50 *****
# Total Loss : 0.1748
# Accuracy   : 93.83 %
# Precision  : 93.91 %
# F1 score   : 93.86 %
#
# ***** Epoch 22 of 50 *****
# Total Loss : 0.3064
# Accuracy   : 94.29 %
# Precision  : 94.28 %
# F1 score   : 94.26 %
#
# ***** Epoch 23 of 50 *****
# Total Loss : 0.2688
# Accuracy   : 94.35 %
# Precision  : 94.40 %
# F1 score   : 94.36 %
#
# ***** Epoch 24 of 50 *****
# Total Loss : 0.2196
# Accuracy   : 94.48 %
# Precision  : 94.46 %
# F1 score   : 94.46 %
#
# ***** Epoch 25 of 50 *****
# Total Loss : 0.2301
# Accuracy   : 94.22 %
# Precision  : 94.21 %
# F1 score   : 94.20 %
#
# ***** Epoch 26 of 50 *****
# Total Loss : 0.1909
# Accuracy   : 94.19 %
# Precision  : 94.19 %
# F1 score   : 94.18 %
#
# ***** Epoch 27 of 50 *****
# Total Loss : 0.1033
# Accuracy   : 94.22 %
# Precision  : 94.22 %
# F1 score   : 94.18 %
#
# ***** Epoch 28 of 50 *****
# Total Loss : 0.1887
# Accuracy   : 95.09 %
# Precision  : 95.07 %
# F1 score   : 95.07 %
#
# ***** Epoch 29 of 50 *****
# Total Loss : 0.1284
# Accuracy   : 94.44 %
# Precision  : 94.48 %
# F1 score   : 94.37 %
#
# ***** Epoch 30 of 50 *****
# Total Loss : 0.0553
# Accuracy   : 94.73 %
# Precision  : 94.86 %
# F1 score   : 94.76 %
#
# ***** Epoch 31 of 50 *****
# Total Loss : 0.1370
# Accuracy   : 95.12 %
# Precision  : 95.14 %
# F1 score   : 95.09 %
#
# ***** Epoch 32 of 50 *****
# Total Loss : 0.1139
# Accuracy   : 94.96 %
# Precision  : 95.05 %
# F1 score   : 94.97 %
#
# ***** Epoch 33 of 50 *****
# Total Loss : 0.0945
# Accuracy   : 95.05 %
# Precision  : 95.03 %
# F1 score   : 95.01 %
#
# ***** Epoch 34 of 50 *****
# Total Loss : 0.1218
# Accuracy   : 95.22 %
# Precision  : 95.22 %
# F1 score   : 95.21 %
#
# ***** Epoch 35 of 50 *****
# Total Loss : 0.0558
# Accuracy   : 95.43 %
# Precision  : 95.43 %
# F1 score   : 95.42 %
#
# ***** Epoch 36 of 50 *****
# Total Loss : 0.2697
# Accuracy   : 95.16 %
# Precision  : 95.14 %
# F1 score   : 95.14 %
#
# ***** Epoch 37 of 50 *****
# Total Loss : 0.1317
# Accuracy   : 95.20 %
# Precision  : 95.18 %
# F1 score   : 95.16 %
#
# ***** Epoch 38 of 50 *****
# Total Loss : 0.1084
# Accuracy   : 95.01 %
# Precision  : 95.01 %
# F1 score   : 94.99 %
#
# ***** Epoch 39 of 50 *****
# Total Loss : 0.0595
# Accuracy   : 95.13 %
# Precision  : 95.17 %
# F1 score   : 95.13 %
#
# ***** Epoch 40 of 50 *****
# Total Loss : 0.1258
# Accuracy   : 95.09 %
# Precision  : 95.17 %
# F1 score   : 95.09 %
#
# ***** Epoch 41 of 50 *****
# Total Loss : 0.1212
# Accuracy   : 95.31 %
# Precision  : 95.35 %
# F1 score   : 95.29 %
#
# ***** Epoch 42 of 50 *****
# Total Loss : 0.1223
# Accuracy   : 94.96 %
# Precision  : 94.95 %
# F1 score   : 94.93 %
#
# ***** Epoch 43 of 50 *****
# Total Loss : 0.2278
# Accuracy   : 95.28 %
# Precision  : 95.27 %
# F1 score   : 95.27 %
#
# ***** Epoch 44 of 50 *****
# Total Loss : 0.0810
# Accuracy   : 95.48 %
# Precision  : 95.50 %
# F1 score   : 95.49 %
#
# ***** Epoch 45 of 50 *****
# Total Loss : 0.0716
# Accuracy   : 95.76 %
# Precision  : 95.78 %
# F1 score   : 95.76 %
#
# ***** Epoch 46 of 50 *****
# Total Loss : 0.1000
# Accuracy   : 95.35 %
# Precision  : 95.37 %
# F1 score   : 95.32 %
#
# ***** Epoch 47 of 50 *****
# Total Loss : 0.0947
# Accuracy   : 95.74 %
# Precision  : 95.83 %
# F1 score   : 95.77 %
#
# ***** Epoch 48 of 50 *****
# Total Loss : 0.1294
# Accuracy   : 95.56 %
# Precision  : 95.60 %
# F1 score   : 95.57 %
#
# ***** Epoch 49 of 50 *****
# Total Loss : 0.0959
# Accuracy   : 95.71 %
# Precision  : 95.78 %
# F1 score   : 95.72 %
#
# ***** Epoch 50 of 50 *****
# Total Loss : 0.1216
# Accuracy   : 95.99 %
# Precision  : 95.99 %
# F1 score   : 95.98 %

# %%
plt.plot(results['accuracy'], label="accuracy")
plt.plot(results['precision'], label="precision")
plt.plot(results['f1_score'], label="f1 score")
plt.legend()
plt.show()

# %%
# loading the models 

model1 = CNN1().to(device)
model2 = CNN2().to(device)
model1.load_state_dict(torch.load("./model1_0.85"))
model2.load_state_dict(torch.load("./model2_0.96"))

print(model1.eval())
print(model2.eval())
# Out:
# CNN1(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# CNN2(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### Test
# First define the `test` function to test owr trained model

# %% [markdown]
# Testing first model

# %%
test(model1, test_dataset, 32, verbose=True)
# Out:
# Accuracy: 0.88, Precision: 0.88, F1 Score: 0.88
# (0.8801000118255615, 0.8812204599380493, 0.8804230690002441)

# %%
test(model2, test_dataset, 32, verbose=True)
# Out:
# Accuracy: 0.93, Precision: 0.93, F1 Score: 0.93
# (0.9259999990463257, 0.9260851740837097, 0.9259423017501831)

# %% [markdown]
# ### Different Optimizers
# In this section we check two different optimizers for the two network above
# The optimizers is:
# 1. SGD
# 2. Adam

# %% [markdown]
# #### First model using **SGD**

# %%
model1_1 = CNN1().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model1_1.parameters(), lr=0.002)

results = train(
              model1_1,
              train_dataset,
              criterion,
              optimizer,
              num_epochs = 100,
              batch_size = 64,
              verbose=True)

# saving the model
torch.save(model1_1.state_dict(), f"./model1_1_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 100 *****
# Total Loss : 1.5840
# Accuracy   : 53.28 %
# Precision  : 50.38 %
# F1 score   : 49.02 %
#
# ***** Epoch 2 of 100 *****
# Total Loss : 1.0354
# Accuracy   : 56.79 %
# Precision  : 54.68 %
# F1 score   : 54.74 %
#
# ***** Epoch 3 of 100 *****
# Total Loss : 1.2277
# Accuracy   : 58.85 %
# Precision  : 57.16 %
# F1 score   : 57.14 %
#
# ***** Epoch 4 of 100 *****
# Total Loss : 0.5663
# Accuracy   : 61.39 %
# Precision  : 60.75 %
# F1 score   : 60.61 %
#
# ***** Epoch 5 of 100 *****
# Total Loss : 0.7808
# Accuracy   : 63.07 %
# Precision  : 62.72 %
# F1 score   : 62.53 %
#
# ***** Epoch 6 of 100 *****
# Total Loss : 1.0064
# Accuracy   : 64.88 %
# Precision  : 64.91 %
# F1 score   : 64.72 %
#
# ***** Epoch 7 of 100 *****
# Total Loss : 0.6908
# Accuracy   : 66.03 %
# Precision  : 65.93 %
# F1 score   : 65.77 %
#
# ***** Epoch 8 of 100 *****
# Total Loss : 1.0844
# Accuracy   : 67.40 %
# Precision  : 67.61 %
# F1 score   : 67.42 %
#
# ***** Epoch 9 of 100 *****
# Total Loss : 0.7148
# Accuracy   : 68.12 %
# Precision  : 68.45 %
# F1 score   : 68.19 %
#
# ***** Epoch 10 of 100 *****
# Total Loss : 0.7808
# Accuracy   : 68.59 %
# Precision  : 68.62 %
# F1 score   : 68.39 %
#
# ***** Epoch 11 of 100 *****
# Total Loss : 0.6522
# Accuracy   : 68.94 %
# Precision  : 69.13 %
# F1 score   : 68.85 %
#
# ***** Epoch 12 of 100 *****
# Total Loss : 0.8519
# Accuracy   : 69.70 %
# Precision  : 70.09 %
# F1 score   : 69.78 %
#
# ***** Epoch 13 of 100 *****
# Total Loss : 0.8466
# Accuracy   : 69.97 %
# Precision  : 70.30 %
# F1 score   : 70.01 %
#
# ***** Epoch 14 of 100 *****
# Total Loss : 1.0461
# Accuracy   : 70.37 %
# Precision  : 70.69 %
# F1 score   : 70.36 %
#
# ***** Epoch 15 of 100 *****
# Total Loss : 0.7067
# Accuracy   : 70.75 %
# Precision  : 71.11 %
# F1 score   : 70.79 %
#
# ***** Epoch 16 of 100 *****
# Total Loss : 0.5823
# Accuracy   : 70.89 %
# Precision  : 71.31 %
# F1 score   : 70.96 %
#
# ***** Epoch 17 of 100 *****
# Total Loss : 0.6295
# Accuracy   : 71.18 %
# Precision  : 71.67 %
# F1 score   : 71.30 %
#
# ***** Epoch 18 of 100 *****
# Total Loss : 0.7745
# Accuracy   : 71.28 %
# Precision  : 71.75 %
# F1 score   : 71.32 %
#
# ***** Epoch 19 of 100 *****
# Total Loss : 0.7575
# Accuracy   : 71.22 %
# Precision  : 72.02 %
# F1 score   : 71.50 %
#
# ***** Epoch 20 of 100 *****
# Total Loss : 0.4480
# Accuracy   : 71.82 %
# Precision  : 72.42 %
# F1 score   : 71.95 %
#
# ***** Epoch 21 of 100 *****
# Total Loss : 0.8343
# Accuracy   : 72.09 %
# Precision  : 72.59 %
# F1 score   : 72.16 %
#
# ***** Epoch 22 of 100 *****
# Total Loss : 1.2803
# Accuracy   : 72.34 %
# Precision  : 72.82 %
# F1 score   : 72.40 %
#
# ***** Epoch 23 of 100 *****
# Total Loss : 0.7808
# Accuracy   : 72.27 %
# Precision  : 72.82 %
# F1 score   : 72.35 %
#
# ***** Epoch 24 of 100 *****
# Total Loss : 0.8119
# Accuracy   : 72.34 %
# Precision  : 73.03 %
# F1 score   : 72.53 %
#
# ***** Epoch 25 of 100 *****
# Total Loss : 0.7410
# Accuracy   : 72.62 %
# Precision  : 73.25 %
# F1 score   : 72.76 %
#
# ***** Epoch 26 of 100 *****
# Total Loss : 0.6380
# Accuracy   : 72.74 %
# Precision  : 73.34 %
# F1 score   : 72.82 %
#
# ***** Epoch 27 of 100 *****
# Total Loss : 0.5296
# Accuracy   : 72.74 %
# Precision  : 73.36 %
# F1 score   : 72.81 %
#
# ***** Epoch 28 of 100 *****
# Total Loss : 0.5766
# Accuracy   : 72.87 %
# Precision  : 73.52 %
# F1 score   : 72.97 %
#
# ***** Epoch 29 of 100 *****
# Total Loss : 0.6972
# Accuracy   : 73.03 %
# Precision  : 73.70 %
# F1 score   : 73.18 %
#
# ***** Epoch 30 of 100 *****
# Total Loss : 0.5159
# Accuracy   : 73.06 %
# Precision  : 73.72 %
# F1 score   : 73.15 %
#
# ***** Epoch 31 of 100 *****
# Total Loss : 0.7940
# Accuracy   : 72.95 %
# Precision  : 73.78 %
# F1 score   : 73.15 %
#
# ***** Epoch 32 of 100 *****
# Total Loss : 1.0250
# Accuracy   : 73.44 %
# Precision  : 74.12 %
# F1 score   : 73.57 %
#
# ***** Epoch 33 of 100 *****
# Total Loss : 0.7906
# Accuracy   : 73.38 %
# Precision  : 74.10 %
# F1 score   : 73.51 %
#
# ***** Epoch 34 of 100 *****
# Total Loss : 0.6191
# Accuracy   : 73.46 %
# Precision  : 74.28 %
# F1 score   : 73.68 %
#
# ***** Epoch 35 of 100 *****
# Total Loss : 0.9061
# Accuracy   : 73.71 %
# Precision  : 74.41 %
# F1 score   : 73.83 %
#
# ***** Epoch 36 of 100 *****
# Total Loss : 0.5895
# Accuracy   : 73.60 %
# Precision  : 74.38 %
# F1 score   : 73.73 %
#
# ***** Epoch 37 of 100 *****
# Total Loss : 0.8780
# Accuracy   : 73.76 %
# Precision  : 74.57 %
# F1 score   : 73.93 %
#
# ***** Epoch 38 of 100 *****
# Total Loss : 0.4268
# Accuracy   : 73.87 %
# Precision  : 74.69 %
# F1 score   : 74.10 %
#
# ***** Epoch 39 of 100 *****
# Total Loss : 0.5723
# Accuracy   : 73.74 %
# Precision  : 74.57 %
# F1 score   : 73.96 %
#
# ***** Epoch 40 of 100 *****
# Total Loss : 0.7649
# Accuracy   : 73.75 %
# Precision  : 74.71 %
# F1 score   : 74.02 %
#
# ***** Epoch 41 of 100 *****
# Total Loss : 0.7776
# Accuracy   : 74.03 %
# Precision  : 74.84 %
# F1 score   : 74.22 %
#
# ***** Epoch 42 of 100 *****
# Total Loss : 0.4863
# Accuracy   : 74.21 %
# Precision  : 75.04 %
# F1 score   : 74.35 %
#
# ***** Epoch 43 of 100 *****
# Total Loss : 1.0676
# Accuracy   : 73.97 %
# Precision  : 74.81 %
# F1 score   : 74.16 %
#
# ***** Epoch 44 of 100 *****
# Total Loss : 0.5865
# Accuracy   : 74.43 %
# Precision  : 75.23 %
# F1 score   : 74.54 %
#
# ***** Epoch 45 of 100 *****
# Total Loss : 0.6664
# Accuracy   : 74.29 %
# Precision  : 75.19 %
# F1 score   : 74.50 %
#
# ***** Epoch 46 of 100 *****
# Total Loss : 0.5250
# Accuracy   : 74.49 %
# Precision  : 75.24 %
# F1 score   : 74.63 %
#
# ***** Epoch 47 of 100 *****
# Total Loss : 0.7064
# Accuracy   : 74.33 %
# Precision  : 75.25 %
# F1 score   : 74.49 %
#
# ***** Epoch 48 of 100 *****
# Total Loss : 0.7172
# Accuracy   : 74.19 %
# Precision  : 75.25 %
# F1 score   : 74.50 %
#
# ***** Epoch 49 of 100 *****
# Total Loss : 0.6658
# Accuracy   : 74.67 %
# Precision  : 75.46 %
# F1 score   : 74.77 %
#
# ***** Epoch 50 of 100 *****
# Total Loss : 0.8572
# Accuracy   : 74.67 %
# Precision  : 75.43 %
# F1 score   : 74.78 %
#
# ***** Epoch 51 of 100 *****
# Total Loss : 0.4775
# Accuracy   : 74.42 %
# Precision  : 75.26 %
# F1 score   : 74.58 %
#
# ***** Epoch 52 of 100 *****
# Total Loss : 0.8612
# Accuracy   : 74.79 %
# Precision  : 75.66 %
# F1 score   : 74.95 %
#
# ***** Epoch 53 of 100 *****
# Total Loss : 0.4320
# Accuracy   : 74.66 %
# Precision  : 75.52 %
# F1 score   : 74.86 %
#
# ***** Epoch 54 of 100 *****
# Total Loss : 0.7605
# Accuracy   : 74.56 %
# Precision  : 75.54 %
# F1 score   : 74.80 %
#
# ***** Epoch 55 of 100 *****
# Total Loss : 0.7619
# Accuracy   : 74.77 %
# Precision  : 75.63 %
# F1 score   : 74.89 %
#
# ***** Epoch 56 of 100 *****
# Total Loss : 0.4339
# Accuracy   : 74.99 %
# Precision  : 75.83 %
# F1 score   : 75.13 %
#
# ***** Epoch 57 of 100 *****
# Total Loss : 0.4470
# Accuracy   : 74.89 %
# Precision  : 75.75 %
# F1 score   : 75.05 %
#
# ***** Epoch 58 of 100 *****
# Total Loss : 0.5699
# Accuracy   : 74.75 %
# Precision  : 75.68 %
# F1 score   : 74.96 %
#
# ***** Epoch 59 of 100 *****
# Total Loss : 0.6936
# Accuracy   : 75.01 %
# Precision  : 75.87 %
# F1 score   : 75.14 %
#
# ***** Epoch 60 of 100 *****
# Total Loss : 0.8277
# Accuracy   : 74.99 %
# Precision  : 75.93 %
# F1 score   : 75.23 %
#
# ***** Epoch 61 of 100 *****
# Total Loss : 0.6900
# Accuracy   : 75.01 %
# Precision  : 75.90 %
# F1 score   : 75.19 %
#
# ***** Epoch 62 of 100 *****
# Total Loss : 0.7918
# Accuracy   : 74.93 %
# Precision  : 75.85 %
# F1 score   : 75.08 %
#
# ***** Epoch 63 of 100 *****
# Total Loss : 0.7214
# Accuracy   : 75.18 %
# Precision  : 76.13 %
# F1 score   : 75.40 %
#
# ***** Epoch 64 of 100 *****
# Total Loss : 0.5368
# Accuracy   : 75.25 %
# Precision  : 76.17 %
# F1 score   : 75.44 %
#
# ***** Epoch 65 of 100 *****
# Total Loss : 0.6212
# Accuracy   : 75.13 %
# Precision  : 76.08 %
# F1 score   : 75.28 %
#
# ***** Epoch 66 of 100 *****
# Total Loss : 0.4257
# Accuracy   : 74.88 %
# Precision  : 75.88 %
# F1 score   : 75.12 %
#
# ***** Epoch 67 of 100 *****
# Total Loss : 0.8291
# Accuracy   : 75.16 %
# Precision  : 76.05 %
# F1 score   : 75.34 %
#
# ***** Epoch 68 of 100 *****
# Total Loss : 0.5212
# Accuracy   : 75.34 %
# Precision  : 76.25 %
# F1 score   : 75.44 %
#
# ***** Epoch 69 of 100 *****
# Total Loss : 0.7782
# Accuracy   : 75.01 %
# Precision  : 76.01 %
# F1 score   : 75.25 %
#
# ***** Epoch 70 of 100 *****
# Total Loss : 0.8646
# Accuracy   : 75.22 %
# Precision  : 76.13 %
# F1 score   : 75.38 %
#
# ***** Epoch 71 of 100 *****
# Total Loss : 0.5682
# Accuracy   : 75.05 %
# Precision  : 76.12 %
# F1 score   : 75.29 %
#
# ***** Epoch 72 of 100 *****
# Total Loss : 0.8585
# Accuracy   : 75.30 %
# Precision  : 76.23 %
# F1 score   : 75.46 %
#
# ***** Epoch 73 of 100 *****
# Total Loss : 0.8095
# Accuracy   : 75.48 %
# Precision  : 76.37 %
# F1 score   : 75.69 %
#
# ***** Epoch 74 of 100 *****
# Total Loss : 0.7682
# Accuracy   : 75.12 %
# Precision  : 76.25 %
# F1 score   : 75.46 %
#
# ***** Epoch 75 of 100 *****
# Total Loss : 0.6035
# Accuracy   : 75.51 %
# Precision  : 76.47 %
# F1 score   : 75.74 %
#
# ***** Epoch 76 of 100 *****
# Total Loss : 0.8017
# Accuracy   : 75.50 %
# Precision  : 76.44 %
# F1 score   : 75.71 %
#
# ***** Epoch 77 of 100 *****
# Total Loss : 0.5210
# Accuracy   : 75.67 %
# Precision  : 76.69 %
# F1 score   : 75.81 %
#
# ***** Epoch 78 of 100 *****
# Total Loss : 0.8903
# Accuracy   : 75.64 %
# Precision  : 76.62 %
# F1 score   : 75.87 %
#
# ***** Epoch 79 of 100 *****
# Total Loss : 0.4484
# Accuracy   : 75.61 %
# Precision  : 76.52 %
# F1 score   : 75.81 %
#
# ***** Epoch 80 of 100 *****
# Total Loss : 0.6818
# Accuracy   : 75.75 %
# Precision  : 76.65 %
# F1 score   : 75.91 %
#
# ***** Epoch 81 of 100 *****
# Total Loss : 1.0429
# Accuracy   : 75.86 %
# Precision  : 76.77 %
# F1 score   : 76.02 %
#
# ***** Epoch 82 of 100 *****
# Total Loss : 0.5266
# Accuracy   : 75.78 %
# Precision  : 76.67 %
# F1 score   : 75.96 %
#
# ***** Epoch 83 of 100 *****
# Total Loss : 0.4161
# Accuracy   : 76.03 %
# Precision  : 76.95 %
# F1 score   : 76.14 %
#
# ***** Epoch 84 of 100 *****
# Total Loss : 0.5209
# Accuracy   : 75.46 %
# Precision  : 76.45 %
# F1 score   : 75.72 %
#
# ***** Epoch 85 of 100 *****
# Total Loss : 0.3572
# Accuracy   : 76.13 %
# Precision  : 77.06 %
# F1 score   : 76.25 %
#
# ***** Epoch 86 of 100 *****
# Total Loss : 0.4972
# Accuracy   : 76.06 %
# Precision  : 76.92 %
# F1 score   : 76.19 %
#
# ***** Epoch 87 of 100 *****
# Total Loss : 0.4445
# Accuracy   : 75.82 %
# Precision  : 76.87 %
# F1 score   : 76.01 %
#
# ***** Epoch 88 of 100 *****
# Total Loss : 0.5673
# Accuracy   : 76.24 %
# Precision  : 77.18 %
# F1 score   : 76.43 %
#
# ***** Epoch 89 of 100 *****
# Total Loss : 0.4818
# Accuracy   : 76.08 %
# Precision  : 77.04 %
# F1 score   : 76.24 %
#
# ***** Epoch 90 of 100 *****
# Total Loss : 0.4761
# Accuracy   : 76.06 %
# Precision  : 77.06 %
# F1 score   : 76.27 %
#
# ***** Epoch 91 of 100 *****
# Total Loss : 0.7200
# Accuracy   : 76.08 %
# Precision  : 77.09 %
# F1 score   : 76.29 %
#
# ***** Epoch 92 of 100 *****
# Total Loss : 0.6778
# Accuracy   : 76.32 %
# Precision  : 77.32 %
# F1 score   : 76.44 %
#
# ***** Epoch 93 of 100 *****
# Total Loss : 0.3760
# Accuracy   : 75.94 %
# Precision  : 77.00 %
# F1 score   : 76.04 %
#
# ***** Epoch 94 of 100 *****
# Total Loss : 0.6986
# Accuracy   : 75.95 %
# Precision  : 76.98 %
# F1 score   : 76.23 %
#
# ***** Epoch 95 of 100 *****
# Total Loss : 0.7057
# Accuracy   : 76.13 %
# Precision  : 77.08 %
# F1 score   : 76.34 %
#
# ***** Epoch 96 of 100 *****
# Total Loss : 0.6289
# Accuracy   : 76.16 %
# Precision  : 77.15 %
# F1 score   : 76.42 %
#
# ***** Epoch 97 of 100 *****
# Total Loss : 0.8116
# Accuracy   : 76.32 %
# Precision  : 77.27 %
# F1 score   : 76.50 %
#
# ***** Epoch 98 of 100 *****
# Total Loss : 0.9830
# Accuracy   : 76.40 %
# Precision  : 77.29 %
# F1 score   : 76.54 %
#
# ***** Epoch 99 of 100 *****
# Total Loss : 0.5304
# Accuracy   : 76.14 %
# Precision  : 77.26 %
# F1 score   : 76.41 %
#
# ***** Epoch 100 of 100 *****
# Total Loss : 0.6996
# Accuracy   : 76.02 %
# Precision  : 76.96 %
# F1 score   : 76.21 %
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-f789c4376de9> in <module>
#      13
#      14 # saving the model
# ---> 15 torch.save(model1_1.state_dict(), f"./model1_1_{results['accuracy']}")
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     374     _check_dill_version(pickle_module)
#     375
# --> 376     with _open_file_like(f, 'wb') as opened_file:
#     377         if _use_new_zipfile_serialization:
#     378             with _open_zipfile_writer(opened_file) as opened_zipfile:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# OSError: [Errno 36] File name too long: './model1_1_[0.5328166484832764, 0.5679333209991455, 0.5885000228881836, 0.6139166951179504, 0.6306666731834412, 0.6488333344459534, 0.6603167057037354, 0.6740000247955322, 0.6811500191688538, 0.6858834028244019, 0.6893832683563232, 0.6970499753952026, 0.699733316898346, 0.7036833167076111, 0.7075166702270508, 0.7088667154312134, 0.7117666602134705, 0.7128166556358337, 0.7122166752815247, 0.7181832790374756, 0.7209333181381226, 0.7233999967575073, 0.7226666212081909, 0.7234333753585815, 0.7262166738510132, 0.727400004863739, 0.7274333238601685, 0.7286666631698608, 0.7303333282470703, 0.7305833101272583, 0.7294666767120361, 0.7344499826431274, 0.7338000535964966, 0.7346166372299194, 0.7370666861534119, 0.735966682434082, 0.7375832796096802, 0.7386833429336548, 0.7373999953269958, 0.737500011920929, 0.7402833104133606, 0.7420666217803955, 0.7396999597549438, 0.7443000078201294, 0.7428833246231079, 0.7448666095733643, 0.7432999610900879, 0.7419333457946777, 0.7466832995414734, 0.7467166781425476, 0.7442499399185181, 0.7479166984558105, 0.7466332912445068, 0.7455500364303589, 0.7476832866668701, 0.7498832941055298, 0.748866617679596, 0.7474833130836487, 0.7500666379928589, 0.7498666644096375, 0.7501333355903625, 0.7493166923522949, 0.7518333196640015, 0.7524833083152771, 0.7512667179107666, 0.7487666606903076, 0.7515833377838135, 0.7533832788467407, 0.7501333355903625, 0.7522000074386597, 0.750499963760376, 0.7529667019844055,...

# %% [markdown]
# #### First model using **Adam**
# This model is train in the default model above you can check above

# %% [markdown]
# #### Second model using **SGD**

# %%
model2_1 = CNN2().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model2_1.parameters(), lr=0.002)

results = train(
              model2_1,
              train_dataset,
              criterion,
              optimizer,
              num_epochs = 50,
              batch_size = 128,
              verbose=True)

# saving the modle
torch.save(model2_1.state_dict(), f"./model2_1_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 50 *****
# Total Loss : 2.3028
# Accuracy   : 10.64 %
# Precision  : 12.35 %
# F1 score   : 3.59 %
#
# ***** Epoch 2 of 50 *****
# Total Loss : 2.2916
# Accuracy   : 12.80 %
# Precision  : 35.77 %
# F1 score   : 7.50 %
#
# ***** Epoch 3 of 50 *****
# Total Loss : 2.2771
# Accuracy   : 19.51 %
# Precision  : 35.98 %
# F1 score   : 14.97 %
#
# ***** Epoch 4 of 50 *****
# Total Loss : 2.2170
# Accuracy   : 25.08 %
# Precision  : 34.41 %
# F1 score   : 17.07 %
#
# ***** Epoch 5 of 50 *****
# Total Loss : 1.2971
# Accuracy   : 50.34 %
# Precision  : 49.69 %
# F1 score   : 47.69 %
#
# ***** Epoch 6 of 50 *****
# Total Loss : 1.0730
# Accuracy   : 57.90 %
# Precision  : 58.59 %
# F1 score   : 56.10 %
#
# ***** Epoch 7 of 50 *****
# Total Loss : 0.9083
# Accuracy   : 62.88 %
# Precision  : 62.34 %
# F1 score   : 60.63 %
#
# ***** Epoch 8 of 50 *****
# Total Loss : 0.8540
# Accuracy   : 65.41 %
# Precision  : 64.51 %
# F1 score   : 64.22 %
#
# ***** Epoch 9 of 50 *****
# Total Loss : 0.8384
# Accuracy   : 67.15 %
# Precision  : 67.13 %
# F1 score   : 65.80 %
#
# ***** Epoch 10 of 50 *****
# Total Loss : 0.6600
# Accuracy   : 69.59 %
# Precision  : 68.54 %
# F1 score   : 68.18 %
#
# ***** Epoch 11 of 50 *****
# Total Loss : 0.7451
# Accuracy   : 71.00 %
# Precision  : 69.95 %
# F1 score   : 70.05 %
#
# ***** Epoch 12 of 50 *****
# Total Loss : 0.7747
# Accuracy   : 69.98 %
# Precision  : 70.27 %
# F1 score   : 68.07 %
#
# ***** Epoch 13 of 50 *****
# Total Loss : 0.5134
# Accuracy   : 72.89 %
# Precision  : 72.40 %
# F1 score   : 70.94 %
#
# ***** Epoch 14 of 50 *****
# Total Loss : 0.7407
# Accuracy   : 73.37 %
# Precision  : 72.50 %
# F1 score   : 71.46 %
#
# ***** Epoch 15 of 50 *****
# Total Loss : 0.7329
# Accuracy   : 73.29 %
# Precision  : 72.73 %
# F1 score   : 72.83 %
#
# ***** Epoch 16 of 50 *****
# Total Loss : 0.7544
# Accuracy   : 74.47 %
# Precision  : 73.58 %
# F1 score   : 73.68 %
#
# ***** Epoch 17 of 50 *****
# Total Loss : 0.8230
# Accuracy   : 74.31 %
# Precision  : 74.27 %
# F1 score   : 74.22 %
#
# ***** Epoch 18 of 50 *****
# Total Loss : 0.6654
# Accuracy   : 75.23 %
# Precision  : 74.35 %
# F1 score   : 74.34 %
#
# ***** Epoch 19 of 50 *****
# Total Loss : 0.4612
# Accuracy   : 76.00 %
# Precision  : 75.29 %
# F1 score   : 75.21 %
#
# ***** Epoch 20 of 50 *****
# Total Loss : 0.4889
# Accuracy   : 76.40 %
# Precision  : 75.64 %
# F1 score   : 75.26 %
#
# ***** Epoch 21 of 50 *****
# Total Loss : 0.6495
# Accuracy   : 76.83 %
# Precision  : 76.24 %
# F1 score   : 75.95 %
#
# ***** Epoch 22 of 50 *****
# Total Loss : 0.5875
# Accuracy   : 76.92 %
# Precision  : 76.28 %
# F1 score   : 75.91 %
#
# ***** Epoch 23 of 50 *****
# Total Loss : 0.7163
# Accuracy   : 77.41 %
# Precision  : 76.48 %
# F1 score   : 76.52 %
#
# ***** Epoch 24 of 50 *****
# Total Loss : 0.6408
# Accuracy   : 77.16 %
# Precision  : 76.70 %
# F1 score   : 76.44 %
#
# ***** Epoch 25 of 50 *****
# Total Loss : 0.6413
# Accuracy   : 77.98 %
# Precision  : 77.22 %
# F1 score   : 77.00 %
#
# ***** Epoch 26 of 50 *****
# Total Loss : 0.6706
# Accuracy   : 78.08 %
# Precision  : 77.60 %
# F1 score   : 77.12 %
#
# ***** Epoch 27 of 50 *****
# Total Loss : 0.6637
# Accuracy   : 77.83 %
# Precision  : 77.90 %
# F1 score   : 76.48 %
#
# ***** Epoch 28 of 50 *****
# Total Loss : 0.5033
# Accuracy   : 78.03 %
# Precision  : 77.88 %
# F1 score   : 77.19 %
#
# ***** Epoch 29 of 50 *****
# Total Loss : 0.5887
# Accuracy   : 78.63 %
# Precision  : 78.68 %
# F1 score   : 78.63 %
#
# ***** Epoch 30 of 50 *****
# Total Loss : 0.5452
# Accuracy   : 79.16 %
# Precision  : 78.65 %
# F1 score   : 78.38 %
#
# ***** Epoch 31 of 50 *****
# Total Loss : 0.4831
# Accuracy   : 79.35 %
# Precision  : 78.96 %
# F1 score   : 78.98 %
#
# ***** Epoch 32 of 50 *****
# Total Loss : 0.6981
# Accuracy   : 79.38 %
# Precision  : 79.10 %
# F1 score   : 79.02 %
#
# ***** Epoch 33 of 50 *****
# Total Loss : 0.6762
# Accuracy   : 79.45 %
# Precision  : 79.40 %
# F1 score   : 79.21 %
#
# ***** Epoch 34 of 50 *****
# Total Loss : 0.4298
# Accuracy   : 79.90 %
# Precision  : 79.38 %
# F1 score   : 79.23 %
#
# ***** Epoch 35 of 50 *****
# Total Loss : 0.6941
# Accuracy   : 80.15 %
# Precision  : 79.84 %
# F1 score   : 79.76 %
#
# ***** Epoch 36 of 50 *****
# Total Loss : 0.5847
# Accuracy   : 80.06 %
# Precision  : 79.79 %
# F1 score   : 79.80 %
#
# ***** Epoch 37 of 50 *****
# Total Loss : 0.5774
# Accuracy   : 80.31 %
# Precision  : 79.96 %
# F1 score   : 79.83 %
#
# ***** Epoch 38 of 50 *****
# Total Loss : 0.4695
# Accuracy   : 80.27 %
# Precision  : 80.12 %
# F1 score   : 79.66 %
#
# ***** Epoch 39 of 50 *****
# Total Loss : 0.4885
# Accuracy   : 80.41 %
# Precision  : 80.07 %
# F1 score   : 80.04 %
#
# ***** Epoch 40 of 50 *****
# Total Loss : 0.8085
# Accuracy   : 80.53 %
# Precision  : 80.50 %
# F1 score   : 80.18 %
#
# ***** Epoch 41 of 50 *****
# Total Loss : 0.6837
# Accuracy   : 80.68 %
# Precision  : 80.51 %
# F1 score   : 79.90 %
#
# ***** Epoch 42 of 50 *****
# Total Loss : 0.5094
# Accuracy   : 80.74 %
# Precision  : 80.66 %
# F1 score   : 79.99 %
#
# ***** Epoch 43 of 50 *****
# Total Loss : 0.6566
# Accuracy   : 80.93 %
# Precision  : 80.72 %
# F1 score   : 80.19 %
#
# ***** Epoch 44 of 50 *****
# Total Loss : 0.4118
# Accuracy   : 81.25 %
# Precision  : 81.17 %
# F1 score   : 81.13 %
#
# ***** Epoch 45 of 50 *****
# Total Loss : 0.3883
# Accuracy   : 81.30 %
# Precision  : 81.10 %
# F1 score   : 81.10 %
#
# ***** Epoch 46 of 50 *****
# Total Loss : 0.4924
# Accuracy   : 81.25 %
# Precision  : 80.97 %
# F1 score   : 80.55 %
#
# ***** Epoch 47 of 50 *****
# Total Loss : 0.4178
# Accuracy   : 81.45 %
# Precision  : 81.29 %
# F1 score   : 81.08 %
#
# ***** Epoch 48 of 50 *****
# Total Loss : 0.2821
# Accuracy   : 81.76 %
# Precision  : 81.60 %
# F1 score   : 81.61 %
#
# ***** Epoch 49 of 50 *****
# Total Loss : 0.4920
# Accuracy   : 81.67 %
# Precision  : 81.81 %
# F1 score   : 81.70 %
#
# ***** Epoch 50 of 50 *****
# Total Loss : 0.4287
# Accuracy   : 81.65 %
# Precision  : 81.22 %
# F1 score   : 81.13 %

# %% [markdown]
# #### Second model using **Adam**

# %%
model2_2 = CNN2().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model2_2.parameters(), lr=0.002)

results = train(
              model2_2,
              train_dataset,
              criterion,
              optimizer,
              num_epochs = 50,
              batch_size = 128,
              verbose=True)

# saving the modle
torch.save(model2_2.state_dict(), f"./model2_2_{results['accuracy'][-1]:.2f}")
# Out:
# ***** Epoch 1 of 50 *****
# Total Loss : 2.2977
# Accuracy   : 11.35 %
# Precision  : 7.42 %
# F1 score   : 4.61 %
#
# ***** Epoch 2 of 50 *****
# Total Loss : 2.3020
# Accuracy   : 12.86 %
# Precision  : 8.41 %
# F1 score   : 6.19 %
#
# ***** Epoch 3 of 50 *****
# Total Loss : 2.2989
# Accuracy   : 13.71 %
# Precision  : 20.23 %
# F1 score   : 6.70 %
#
# ***** Epoch 4 of 50 *****
# Total Loss : 2.2935
# Accuracy   : 12.86 %
# Precision  : 14.08 %
# F1 score   : 5.72 %
#
# ***** Epoch 5 of 50 *****
# Total Loss : 2.2482
# Accuracy   : 14.21 %
# Precision  : 19.10 %
# F1 score   : 7.25 %
#
# ***** Epoch 6 of 50 *****
# Total Loss : 1.8964
# Accuracy   : 41.48 %
# Precision  : 38.20 %
# F1 score   : 37.93 %
#
# ***** Epoch 7 of 50 *****
# Total Loss : 1.0887
# Accuracy   : 52.10 %
# Precision  : 52.11 %
# F1 score   : 50.08 %
#
# ***** Epoch 8 of 50 *****
# Total Loss : 1.0914
# Accuracy   : 59.13 %
# Precision  : 58.42 %
# F1 score   : 57.07 %
#
# ***** Epoch 9 of 50 *****
# Total Loss : 0.9492
# Accuracy   : 61.79 %
# Precision  : 60.61 %
# F1 score   : 60.80 %
#
# ***** Epoch 10 of 50 *****
# Total Loss : 0.9557
# Accuracy   : 64.42 %
# Precision  : 63.90 %
# F1 score   : 63.38 %
#
# ***** Epoch 11 of 50 *****
# Total Loss : 1.0768
# Accuracy   : 65.98 %
# Precision  : 65.80 %
# F1 score   : 65.28 %
#
# ***** Epoch 12 of 50 *****
# Total Loss : 0.7972
# Accuracy   : 68.32 %
# Precision  : 67.58 %
# F1 score   : 67.51 %
#
# ***** Epoch 13 of 50 *****
# Total Loss : 0.7285
# Accuracy   : 69.48 %
# Precision  : 69.31 %
# F1 score   : 67.16 %
#
# ***** Epoch 14 of 50 *****
# Total Loss : 0.8777
# Accuracy   : 70.68 %
# Precision  : 70.23 %
# F1 score   : 68.73 %
#
# ***** Epoch 15 of 50 *****
# Total Loss : 0.8641
# Accuracy   : 71.16 %
# Precision  : 69.80 %
# F1 score   : 69.82 %
#
# ***** Epoch 16 of 50 *****
# Total Loss : 0.7515
# Accuracy   : 70.49 %
# Precision  : 70.91 %
# F1 score   : 70.25 %
#
# ***** Epoch 17 of 50 *****
# Total Loss : 0.7401
# Accuracy   : 72.30 %
# Precision  : 70.94 %
# F1 score   : 71.06 %
#
# ***** Epoch 18 of 50 *****
# Total Loss : 0.7580
# Accuracy   : 72.42 %
# Precision  : 71.90 %
# F1 score   : 71.47 %
#
# ***** Epoch 19 of 50 *****
# Total Loss : 0.5760
# Accuracy   : 73.29 %
# Precision  : 72.32 %
# F1 score   : 72.58 %
#
# ***** Epoch 20 of 50 *****
# Total Loss : 0.7051
# Accuracy   : 72.45 %
# Precision  : 72.85 %
# F1 score   : 71.97 %
#
# ***** Epoch 21 of 50 *****
# Total Loss : 0.7717
# Accuracy   : 74.33 %
# Precision  : 74.08 %
# F1 score   : 72.47 %
#
# ***** Epoch 22 of 50 *****
# Total Loss : 0.7672
# Accuracy   : 75.00 %
# Precision  : 74.04 %
# F1 score   : 73.26 %
#
# ***** Epoch 23 of 50 *****
# Total Loss : 0.6139
# Accuracy   : 75.32 %
# Precision  : 74.43 %
# F1 score   : 74.51 %
#
# ***** Epoch 24 of 50 *****
# Total Loss : 0.6164
# Accuracy   : 75.25 %
# Precision  : 74.52 %
# F1 score   : 73.95 %
#
# ***** Epoch 25 of 50 *****
# Total Loss : 0.5440
# Accuracy   : 75.38 %
# Precision  : 75.09 %
# F1 score   : 73.72 %
#
# ***** Epoch 26 of 50 *****
# Total Loss : 0.6554
# Accuracy   : 76.24 %
# Precision  : 75.59 %
# F1 score   : 75.42 %
#
# ***** Epoch 27 of 50 *****
# Total Loss : 0.7305
# Accuracy   : 76.36 %
# Precision  : 75.41 %
# F1 score   : 75.36 %
#
# ***** Epoch 28 of 50 *****
# Total Loss : 0.5859
# Accuracy   : 76.90 %
# Precision  : 76.41 %
# F1 score   : 75.91 %
#
# ***** Epoch 29 of 50 *****
# Total Loss : 0.5978
# Accuracy   : 77.18 %
# Precision  : 76.33 %
# F1 score   : 75.77 %
#
# ***** Epoch 30 of 50 *****
# Total Loss : 0.6911
# Accuracy   : 76.50 %
# Precision  : 76.49 %
# F1 score   : 75.78 %
#
# ***** Epoch 31 of 50 *****
# Total Loss : 0.6064
# Accuracy   : 77.53 %
# Precision  : 77.10 %
# F1 score   : 76.44 %
#
# ***** Epoch 32 of 50 *****
# Total Loss : 0.6720
# Accuracy   : 77.85 %
# Precision  : 77.34 %
# F1 score   : 77.23 %
#
# ***** Epoch 33 of 50 *****
# Total Loss : 0.5429
# Accuracy   : 77.95 %
# Precision  : 77.45 %
# F1 score   : 76.98 %
#
# ***** Epoch 34 of 50 *****
# Total Loss : 0.6355
# Accuracy   : 77.90 %
# Precision  : 77.52 %
# F1 score   : 76.93 %
#
# ***** Epoch 35 of 50 *****
# Total Loss : 0.6319
# Accuracy   : 78.72 %
# Precision  : 78.22 %
# F1 score   : 78.00 %
#
# ***** Epoch 36 of 50 *****
# Total Loss : 0.5046
# Accuracy   : 78.88 %
# Precision  : 78.90 %
# F1 score   : 78.83 %
#
# ***** Epoch 37 of 50 *****
# Total Loss : 0.5402
# Accuracy   : 78.67 %
# Precision  : 78.64 %
# F1 score   : 78.15 %
#
# ***** Epoch 38 of 50 *****
# Total Loss : 0.7646
# Accuracy   : 78.90 %
# Precision  : 78.74 %
# F1 score   : 78.17 %
#
# ***** Epoch 39 of 50 *****
# Total Loss : 0.3580
# Accuracy   : 79.27 %
# Precision  : 79.03 %
# F1 score   : 78.49 %
#
# ***** Epoch 40 of 50 *****
# Total Loss : 0.4310
# Accuracy   : 79.61 %
# Precision  : 79.40 %
# F1 score   : 79.39 %
#
# ***** Epoch 41 of 50 *****
# Total Loss : 0.5011
# Accuracy   : 79.79 %
# Precision  : 79.41 %
# F1 score   : 79.29 %
#
# ***** Epoch 42 of 50 *****
# Total Loss : 0.3810
# Accuracy   : 79.75 %
# Precision  : 79.22 %
# F1 score   : 79.11 %
#
# ***** Epoch 43 of 50 *****
# Total Loss : 0.7262
# Accuracy   : 80.03 %
# Precision  : 79.55 %
# F1 score   : 79.43 %
#
# ***** Epoch 44 of 50 *****
# Total Loss : 0.6375
# Accuracy   : 80.12 %
# Precision  : 79.78 %
# F1 score   : 79.57 %
#
# ***** Epoch 45 of 50 *****
# Total Loss : 0.5850
# Accuracy   : 80.10 %
# Precision  : 79.92 %
# F1 score   : 79.70 %
#
# ***** Epoch 46 of 50 *****
# Total Loss : 0.4560
# Accuracy   : 80.55 %
# Precision  : 80.10 %
# F1 score   : 80.05 %
#
# ***** Epoch 47 of 50 *****
# Total Loss : 0.5928
# Accuracy   : 80.32 %
# Precision  : 80.27 %
# F1 score   : 80.04 %
#
# ***** Epoch 48 of 50 *****
# Total Loss : 0.6185
# Accuracy   : 80.69 %
# Precision  : 80.29 %
# F1 score   : 80.24 %
#
# ***** Epoch 49 of 50 *****
# Total Loss : 0.4379
# Accuracy   : 80.64 %
# Precision  : 80.36 %
# F1 score   : 80.22 %
#
# ***** Epoch 50 of 50 *****
# Total Loss : 0.4205
# Accuracy   : 81.06 %
# Precision  : 80.62 %
# F1 score   : 80.54 %
